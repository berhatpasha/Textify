# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#data = pd.read_excel('resmiyet.xlsx')
# data = pd.read_excel('resmiyetV2.xlsx')
data = pd.read_excel('resmiyetV2.xlsx')

# %%
data.head(5)
# Out:
#                                          Cümle  Resmiyet
# 0                 Toplantı saati değiştirildi.        10
# 1              Size nasıl yardımcı olabilirim?         8
# 2  Görüşme planlarımızı netleştirebilir miyiz?        10
# 3    Lütfen bana detayları iletebilir misiniz?         7
# 4   Şirket politikası gereği bunu yapamıyoruz.        10

# %%
vector = TfidfVectorizer()
x = vector.fit_transform(data['Cümle'])
y = data["Resmiyet"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
simulator = model.predict(x_test)

# %%
print(mean_squared_error(y_test,simulator))
model.score(x_test,y_test)
# Out:
# 0.9946861146179033
# 0.8837530741708295

# %%
model.predict(vector.transform(["Projeyi tamamladınız mı?"]))
# Out:
# array([5.22966655])

# %%
model.predict(vector.transform(["Merhaba, nasıl olduğunuzdan eminim ama bu hafta biraz daha yoğun olacağım. Eğer uygun görürseniz, bu hafta sonu bir araya gelip daha detaylı bir şekilde konuşabiliriz. Ne zaman müsait olursanız, haber verirseniz sevinirim."]))
# Out:
# array([4.96302841])

# %%
model.predict(vector.transform(['Sayın yetkili, başvurunuz değerlendirmeye alınmıştır.']))
# Out:
# array([5.58703051])

# %%
model.predict(vector.transform(['Sayın Müşterimiz, başvurunuz tarafımıza ulaşmış olup, ilgili birim tarafından detaylı olarak incelendikten sonra en kısa sürede tarafınıza geri dönüş sağlanacaktır. İlginiz için teşekkür ederiz.']))
# Out:
# array([7.71116058])

# %%
model.predict(vector.transform(['']))
# Out:
# array([5.58703051])

# %%
print(mean_squared_error(y_test,simulator))
# Out:
# 0.9946861146179033

# %%
model.coef_
# Out:
# array([-1.05146385,  1.45648402, -1.65858122,  0.40292624, -2.52837763,
#        -1.40923098,  1.0421634 ,  2.01451411, -2.06760231,  1.28552442,
#        -1.62829033,  0.40292624, -0.16285596, -1.43027726, -1.5907511 ,
#        -2.53353857, -0.08668214, -0.4691511 , -1.31340796, -0.43117859,
#        -0.95447912,  1.71056535, -1.91903269,  1.0421634 ,  1.45648402,
#         1.13771716,  1.50818934,  1.13771716,  1.43360166,  1.70486813,
#         1.38698524,  1.69166901, -1.91903269,  1.38698524,  1.55194791,
#        -0.87953626, -1.40923098,  1.71056535,  1.45648402, -1.77776811,
#        -1.65858122, -0.95447912,  1.57873393,  1.45648402, -1.65681578,
#        -2.53353857,  1.38698524, -2.02686858, -0.92498986, -2.06760231,
#         1.0421634 ,  1.71056535,  0.70462781, -1.77776811, -0.95447912,
#        -1.77776811, -1.40923098, -2.54243254,  0.40292624, -1.40923098,
#         1.71056535, -0.95447912,  1.0421634 , -0.95447912, -1.05146385,
#        -1.77776811,  0.40292624,  2.66341185,  0.84224891, -0.35736396,
#        -2.54243254, -2.52837763,  1.14655982, -0.08668214,  1.57873393,
#        -1.43136159,  1.14655982,  0.35469429,  1.28552442,  1.15008085,
#         1.57873393, -0.35736396,  1.55194791,  1.28552442,  1.38698524,
#         1.43360166,  1.38698524,  0.35469429,  1.50818934,  1.69166901,
#         0.35469429, -1.65858122,  2.01366779,  1.70486813,  2.01451411,
#        -1.43136159,  1.28552442, -1.31340796,  1.13771716, -1.05146385,
#         1.28552442,  1.43360166,  1.70486813,  2.11351628,  1.69166901,
#         1.15008085,  1.38698524,  0.69649144,  1.13771716, -1.43136159,
#        -0.16285596,  1.13771716,  1.55194791,  1.14655982,  0.69649144,
#        -2.02686858, -1.31340796, -1.05146385, -0.87953626, -0.08668214,
#        -1.91903269, -3.07558365,  2.01451411, -1.31340796, -1.40923098,
#         1.55194791])

# %%
futures = vector.get_feature_names_out()
vector.get_feature_names_out()
# Out:
# array(['aldım', 'anlaşmanın', 'arkadaşlarla', 'açabilir', 'aşkım',
#        'bakmayın', 'bana', 'başlatılmıştır', 'beklemiyordum', 'belli',
#        'bir', 'biraz', 'birlikte', 'bu', 'bugün', 'buluşalım',
#        'buluşuyoruz', 'bunu', 'böyle', 'daha', 'defa', 'departmanla',
#        'ders', 'detayları', 'detaylarını', 'değerlendireceğim',
#        'değiştirildi', 'dönüş', 'edebilir', 'ederim', 'edilmesi',
#        'erkenden', 'gerekiyor', 'gerekmektedir', 'gereği', 'gerçekten',
#        'geç', 'geçildi', 'geçireceğim', 'gidelim', 'gittik', 'gördüm',
#        'görüşme', 'gözden', 'güzel', 'hadi', 'hareket', 'harikaydı',
#        'hava', 'hiç', 'iletebilir', 'iletişime', 'için', 'içmeye',
#        'kadar', 'kahve', 'kaldım', 'kanka', 'konuyu', 'kusura', 'lgili',
#        'lk', 'lütfen', 'manzara', 'memnunum', 'mi', 'misin', 'misiniz',
#        'miyiz', 'mı', 'napıyon', 'napıyosun', 'nasıl', 'ne',
#        'netleştirebilir', 'of', 'olabilirim', 'olacaktı', 'oldu',
#        'paylaşabilir', 'planlarımızı', 'planın', 'politikası', 'proje',
#        'prosedürlere', 'randevunuzu', 'resmî', 'ricam', 'saati', 'sabah',
#        'senden', 'sinemaya', 'size', 'sunum', 'süreciniz', 'sıkıldım',
#        'tarihi', 'tatlı', 'teklifinizi', 'telefon', 'teslim', 'teyit',
#        'teşekkür', 'toplantı', 'toplantımız', 'tutanaklarını', 'uygun',
#        'var', 've', 'ya', 'yapabilir', 'yapacağım', 'yapamıyoruz',
#        'yardımcı', 'yarın', 'yemek', 'yememiştim', 'yeni', 'yoruldum',
#        'zaman', 'çalışmam', 'çok', 'ödeme', 'önce', 'şe', 'şirket'],
#       dtype=object)

# %%
with open('database', "r") as file:
    text = file.read()

words = text.lower().split()

def newWordBefore(search_phrase):
    search_words = search_phrase.split()

    for start in range(len(search_words)):
        sub_phrase = search_words[start:]
        sub_length = len(sub_phrase)

        for i in range(len(words) - sub_length + 1):
            if words[i:i + sub_length] == sub_phrase:
                prev_word = words[i - 1] if i > 0 else None  # Bir önceki kelimeyi bul
                position = i + 1
                print(f"Cümle: '{' '.join(sub_phrase)}' {position}. kelime, önceki kelime: '{prev_word}'." if prev_word else f"Cümle: '{' '.join(sub_phrase)}' {position}. kelime, önceki kelime: Yok.")

        print("-" * 50)

############################################################

def newWordNext(search_phrase):
    search_words = search_phrase.split()


    for start in range(len(search_words)):
        sub_phrase = search_words[start:]
        sub_length = len(sub_phrase)

        for i in range(len(words) - sub_length + 1):
            if words[i:i + sub_length] == sub_phrase:
                next_word = words[i + sub_length] if i + sub_length < len(words) else None
                position = i + 1
                print(f"Cümle: '{' '.join(sub_phrase)}' {position}. kelime, bir sonraki kelime: '{next_word}'." if next_word else f"Cümle: '{' '.join(sub_phrase)}' {position}. kelime, bir sonraki kelime: Yok.")

        print("-" * 50)

# %%
##
## indirgeme modülü

from difflib import get_close_matches

def reWrite(cumle, futures, esik=0.85):
    kelimeler = cumle.split()
    duzeltilmis_kelimeler = []

    for kelime in kelimeler:
        yakin_kelimeler = get_close_matches(kelime, futures, n=1, cutoff=esik)
        if yakin_kelimeler:
            duzeltilmis_kelimeler.append(yakin_kelimeler[0])
        else:
            duzeltilmis_kelimeler.append(kelime)

    return " ".join(duzeltilmis_kelimeler)



# Örnek cümle
cumle = "merhava arkadaşlar"

# Çalıştır
duzgun_cumle = reWrite(cumle, futures)
print(duzgun_cumle)
# Out:
# merhava arkadaşlarla

# %%
 while True:
    search_phrase = input("Cümle: ").strip()
    search_words = search_phrase.split()

    temp = 0
    for word in search_words:
      temp += model.predict(vector.transform([reWrite(word, futures)]))
      print(temp)

    ort = temp / len(search_words) # cümledeki kelimelerin ortalama ağırlık değeri
    print(f"ortalama ağırlık değeri = {ort}")

    print("Cümle taranıyor...")
    for word in search_words:
      if abs(model.predict(vector.transform([reWrite(word, futures)])) - ort) >= 1:
        print(f"yakalanan kelime >> '{word}'")
        InputSet = " ".join(search_words[:search_words.index(word)]) # algoritmaya girecek kısım
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-5c3e479b914e> in <cell line: 0>()
#       1 while True:
# ----> 2    search_phrase = input("Cümle: ").strip()
#       3    search_words = search_phrase.split()
#       4
#       5    temp = 0
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
### TEST MODÜLÜ

#newWordNext("bir gün")
newWordBefore("bir gün")
# Out:
# Streaming output truncated to the last 5000 lines.
# Cümle: 'gün' 8746866. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8746876. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8746890. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8746906. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8746934. kelime, önceki kelime: '14'.
# Cümle: 'gün' 8746946. kelime, önceki kelime: '14'.
# Cümle: 'gün' 8746957. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8746965. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8746977. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8746989. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747001. kelime, önceki kelime: '180'.
# Cümle: 'gün' 8747009. kelime, önceki kelime: '21'.
# Cümle: 'gün' 8747018. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747026. kelime, önceki kelime: '360'.
# Cümle: 'gün' 8747037. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747060. kelime, önceki kelime: '15'.
# Cümle: 'gün' 8747076. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747087. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747101. kelime, önceki kelime: '60'.
# Cümle: 'gün' 8747130. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747147. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747155. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747177. kelime, önceki kelime: '150'.
# Cümle: 'gün' 8747193. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747203. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747215. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747223. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747231. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747242. kelime, önceki kelime: '10'.
# Cümle: 'gün' 8747271. kelime, önceki kelime: '15'.
# Cümle: 'gün' 8747531. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747537. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747545. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747577. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747608. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747616. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747633. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747653. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747661. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747678. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747686. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747694. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747702. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747728. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747749. kelime, önceki kelime: '31'.
# Cümle: 'gün' 8747774. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747783. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747797. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8747807. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747820. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747828. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747849. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747862. kelime, önceki kelime: '60'.
# Cümle: 'gün' 8747873. kelime, önceki kelime: '14'.
# Cümle: 'gün' 8747882. kelime, önceki kelime: '60'.
# Cümle: 'gün' 8747913. kelime, önceki kelime: '31'.
# Cümle: 'gün' 8747921. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747932. kelime, önceki kelime: '30'.
# Cümle: 'gün' 8747958. kelime, önceki kelime: '90'.
# Cümle: 'gün' 8752380. kelime, önceki kelime: '15'.
# Cümle: 'gün' 8767137. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 8767329. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 8779045. kelime, önceki kelime: '44'.
# Cümle: 'gün' 8784617. kelime, önceki kelime: '121'.
# Cümle: 'gün' 8784634. kelime, önceki kelime: '212'.
# Cümle: 'gün' 8784650. kelime, önceki kelime: '126'.
# Cümle: 'gün' 8784688. kelime, önceki kelime: '78'.
# Cümle: 'gün' 8784709. kelime, önceki kelime: '106'.
# Cümle: 'gün' 8784732. kelime, önceki kelime: '120'.
# Cümle: 'gün' 8784751. kelime, önceki kelime: '248'.
# Cümle: 'gün' 8784769. kelime, önceki kelime: '116'.
# Cümle: 'gün' 8784788. kelime, önceki kelime: '109'.
# Cümle: 'gün' 8784810. kelime, önceki kelime: '101'.
# Cümle: 'gün' 8784829. kelime, önceki kelime: '210'.
# Cümle: 'gün' 8784845. kelime, önceki kelime: '62'.
# Cümle: 'gün' 8794123. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 8794185. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 8808907. kelime, önceki kelime: 'istemiştir.'.
# Cümle: 'gün' 8808919. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 8895966. kelime, önceki kelime: 'elli'.
# Cümle: 'gün' 8895977. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 8911253. kelime, önceki kelime: ']'.
# Cümle: 'gün' 8911596. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 8923199. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 8923265. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 8929756. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 8940953. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 8940955. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 8961185. kelime, önceki kelime: '222'.
# Cümle: 'gün' 8972816. kelime, önceki kelime: '35'.
# Cümle: 'gün' 8974040. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 8974131. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 8974168. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 8980999. kelime, önceki kelime: 'bu'.
# Cümle: 'gün' 9011766. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9014111. kelime, önceki kelime: 'bölü'.
# Cümle: 'gün' 9017171. kelime, önceki kelime: 'sonuçlar'.
# Cümle: 'gün' 9023931. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 9029188. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9029286. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9029302. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9029393. kelime, önceki kelime: '2015-:'.
# Cümle: 'gün' 9030501. kelime, önceki kelime: '8.'.
# Cümle: 'gün' 9030598. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 9033331. kelime, önceki kelime: '1993-2011:'.
# Cümle: 'gün' 9033655. kelime, önceki kelime: '32.'.
# Cümle: 'gün' 9034407. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9035328. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9052557. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9060271. kelime, önceki kelime: '1'.
# Cümle: 'gün' 9060665. kelime, önceki kelime: 'yapı'.
# Cümle: 'gün' 9090286. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9099740. kelime, önceki kelime: 'sekiz'.
# Cümle: 'gün' 9113338. kelime, önceki kelime: '-'.
# Cümle: 'gün' 9126750. kelime, önceki kelime: 'mehmet'.
# Cümle: 'gün' 9132095. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 9139233. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9145625. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9153220. kelime, önceki kelime: '24'.
# Cümle: 'gün' 9153364. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9154901. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9189272. kelime, önceki kelime: 'kazandığı'.
# Cümle: 'gün' 9228375. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9240750. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 9241066. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9241187. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9241372. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9242815. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9243494. kelime, önceki kelime: 'yeniden'.
# Cümle: 'gün' 9261202. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9261456. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9262320. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9262344. kelime, önceki kelime: 'sekiz'.
# Cümle: 'gün' 9296433. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 9313120. kelime, önceki kelime: '10'.
# Cümle: 'gün' 9316017. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 9319910. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9322143. kelime, önceki kelime: 'otuz'.
# Cümle: 'gün' 9322218. kelime, önceki kelime: '30'.
# Cümle: 'gün' 9327579. kelime, önceki kelime: 'ayarlanmış'.
# Cümle: 'gün' 9329567. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 9329611. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 9332548. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9332586. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 9337795. kelime, önceki kelime: 'mehmet'.
# Cümle: 'gün' 9340725. kelime, önceki kelime: 'oldu.10'.
# Cümle: 'gün' 9352960. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 9362835. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9370230. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9370242. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9381484. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9391318. kelime, önceki kelime: 'getirdiği'.
# Cümle: 'gün' 9392755. kelime, önceki kelime: 'önceki'.
# Cümle: 'gün' 9394921. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9408684. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9408914. kelime, önceki kelime: '3'.
# Cümle: 'gün' 9409317. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9411636. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 9411991. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 9415265. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9415920. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9429191. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9432879. kelime, önceki kelime: '('.
# Cümle: 'gün' 9432933. kelime, önceki kelime: '/'.
# Cümle: 'gün' 9437215. kelime, önceki kelime: '2'.
# Cümle: 'gün' 9437339. kelime, önceki kelime: '2'.
# Cümle: 'gün' 9441600. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 9444158. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9450790. kelime, önceki kelime: ']'.
# Cümle: 'gün' 9451072. kelime, önceki kelime: 'bu'.
# Cümle: 'gün' 9459911. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9479317. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 9481332. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 9481732. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9484782. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 9484843. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9484873. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9488701. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9488993. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 9489606. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 9489748. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9489790. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 9495444. kelime, önceki kelime: '10'.
# Cümle: 'gün' 9499100. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9535889. kelime, önceki kelime: '28'.
# Cümle: 'gün' 9535894. kelime, önceki kelime: '(2004)'.
# Cümle: 'gün' 9536177. kelime, önceki kelime: '28'.
# Cümle: 'gün' 9536184. kelime, önceki kelime: '·'.
# Cümle: 'gün' 9549332. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9578716. kelime, önceki kelime: '184'.
# Cümle: 'gün' 9579144. kelime, önceki kelime: '17'.
# Cümle: 'gün' 9588966. kelime, önceki kelime: 've'.
# Cümle: 'gün' 9589592. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9592420. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 9598125. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9599910. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 9604697. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 9604711. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 9611790. kelime, önceki kelime: '124'.
# Cümle: 'gün' 9618180. kelime, önceki kelime: 'üçüncü'.
# Cümle: 'gün' 9619081. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 9626399. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9630078. kelime, önceki kelime: 've'.
# Cümle: 'gün' 9656249. kelime, önceki kelime: 'izleyen'.
# Cümle: 'gün' 9673999. kelime, önceki kelime: '10'.
# Cümle: 'gün' 9675627. kelime, önceki kelime: '21'.
# Cümle: 'gün' 9675831. kelime, önceki kelime: 'sıcaklığının'.
# Cümle: 'gün' 9687706. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9704588. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9721422. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9721458. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 9721485. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9728280. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 9745463. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 9745829. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9756312. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 9769081. kelime, önceki kelime: '(90'.
# Cümle: 'gün' 9779657. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9780041. kelime, önceki kelime: 've'.
# Cümle: 'gün' 9802789. kelime, önceki kelime: '(8'.
# Cümle: 'gün' 9805955. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9806118. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9806462. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9806655. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9817189. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9824240. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9840910. kelime, önceki kelime: 'yaptıkları'.
# Cümle: 'gün' 9842031. kelime, önceki kelime: 'bağlıydı.her'.
# Cümle: 'gün' 9867742. kelime, önceki kelime: 'yayımlandığı'.
# Cümle: 'gün' 9878705. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 9882562. kelime, önceki kelime: '30'.
# Cümle: 'gün' 9882571. kelime, önceki kelime: '29'.
# Cümle: 'gün' 9883769. kelime, önceki kelime: 'bozoklar'.
# Cümle: 'gün' 9884829. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9888898. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9889325. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 9891473. kelime, önceki kelime: ')'.
# Cümle: 'gün' 9891800. kelime, önceki kelime: 'yoğunluğunu,'.
# Cümle: 'gün' 9891878. kelime, önceki kelime: 'teoriler,'.
# Cümle: 'gün' 9899358. kelime, önceki kelime: '7'.
# Cümle: 'gün' 9906233. kelime, önceki kelime: '14'.
# Cümle: 'gün' 9906237. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 9914862. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9920678. kelime, önceki kelime: 'salih'.
# Cümle: 'gün' 9921611. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9922965. kelime, önceki kelime: '10'.
# Cümle: 'gün' 9954829. kelime, önceki kelime: '7'.
# Cümle: 'gün' 9956416. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 9968335. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 9969089. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 9975814. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 9984122. kelime, önceki kelime: '9'.
# Cümle: 'gün' 9984132. kelime, önceki kelime: '11'.
# Cümle: 'gün' 9986656. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 9995733. kelime, önceki kelime: '364'.
# Cümle: 'gün' 10012455. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 10030704. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10030966. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10062639. kelime, önceki kelime: '172'.
# Cümle: 'gün' 10065452. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10070654. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 10092456. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 10092476. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10092511. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 10097492. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10098233. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10098739. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 10116874. kelime, önceki kelime: '20'.
# Cümle: 'gün' 10117221. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10127731. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10145923. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10145953. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10154449. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 10154851. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 10192399. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10205759. kelime, önceki kelime: '15'.
# Cümle: 'gün' 10209939. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 10219621. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10224605. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10233794. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 10235901. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10241389. kelime, önceki kelime: '"her'.
# Cümle: 'gün' 10263775. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 10289830. kelime, önceki kelime: 'fazla'.
# Cümle: 'gün' 10295338. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10304366. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10305307. kelime, önceki kelime: 'bi''.
# Cümle: 'gün' 10323539. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10357820. kelime, önceki kelime: ']'.
# Cümle: 'gün' 10388391. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10388803. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10394965. kelime, önceki kelime: '(39'.
# Cümle: 'gün' 10397677. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 10398402. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10398504. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10398578. kelime, önceki kelime: '·'.
# Cümle: 'gün' 10406693. kelime, önceki kelime: '28'.
# Cümle: 'gün' 10407411. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 10407430. kelime, önceki kelime: 'otuz'.
# Cümle: 'gün' 10407545. kelime, önceki kelime: 'otuz'.
# Cümle: 'gün' 10407887. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10431282. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10436321. kelime, önceki kelime: '12'.
# Cümle: 'gün' 10436927. kelime, önceki kelime: 'güzel'.
# Cümle: 'gün' 10454805. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10465327. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10475859. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 10479424. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10484539. kelime, önceki kelime: '3'.
# Cümle: 'gün' 10495195. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10549545. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10553088. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10557152. kelime, önceki kelime: 'kara'.
# Cümle: 'gün' 10579396. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 10579453. kelime, önceki kelime: '2'.
# Cümle: 'gün' 10579587. kelime, önceki kelime: '1.'.
# Cümle: 'gün' 10579644. kelime, önceki kelime: '2.'.
# Cümle: 'gün' 10595669. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 10633349. kelime, önceki kelime: '234'.
# Cümle: 'gün' 10633493. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 10633552. kelime, önceki kelime: '17'.
# Cümle: 'gün' 10633594. kelime, önceki kelime: 'sıcaklıkları,'.
# Cümle: 'gün' 10636172. kelime, önceki kelime: 'doğduğu'.
# Cümle: 'gün' 10643256. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10643542. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10649323. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 10663127. kelime, önceki kelime: 've'.
# Cümle: 'gün' 10665756. kelime, önceki kelime: '2,87'.
# Cümle: 'gün' 10666764. kelime, önceki kelime: '11.5'.
# Cümle: 'gün' 10683290. kelime, önceki kelime: '•'.
# Cümle: 'gün' 10689183. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 10714918. kelime, önceki kelime: '249'.
# Cümle: 'gün' 10722178. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 10722424. kelime, önceki kelime: '(o'.
# Cümle: 'gün' 10725321. kelime, önceki kelime: '22'.
# Cümle: 'gün' 10732198. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 10743570. kelime, önceki kelime: ']'.
# Cümle: 'gün' 10743697. kelime, önceki kelime: 'içeren,'.
# Cümle: 'gün' 10744117. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 10749501. kelime, önceki kelime: 'ziya'.
# Cümle: 'gün' 10757067. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10760069. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10764344. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 10764358. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 10765179. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 10777721. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10779446. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10780044. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10781074. kelime, önceki kelime: 'aydın'.
# Cümle: 'gün' 10782078. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10785970. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 10786094. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10786236. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10794214. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10794907. kelime, önceki kelime: '23'.
# Cümle: 'gün' 10795042. kelime, önceki kelime: '372,57'.
# Cümle: 'gün' 10795933. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10834324. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 10834726. kelime, önceki kelime: '/'.
# Cümle: 'gün' 10839697. kelime, önceki kelime: '715'.
# Cümle: 'gün' 10845999. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 10846005. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10866147. kelime, önceki kelime: '10'.
# Cümle: 'gün' 10883499. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10890691. kelime, önceki kelime: 'kırk'.
# Cümle: 'gün' 10902483. kelime, önceki kelime: '19'.
# Cümle: 'gün' 10902517. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10916076. kelime, önceki kelime: '30'.
# Cümle: 'gün' 10918248. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 10919502. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 10919652. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 10921044. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10922463. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10929149. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10929210. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10940799. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 10940892. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10943977. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10945465. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 10975162. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 10975179. kelime, önceki kelime: '(303)'.
# Cümle: 'gün' 10975474. kelime, önceki kelime: '(79'.
# Cümle: 'gün' 10975515. kelime, önceki kelime: '94'.
# Cümle: 'gün' 10976056. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 10976229. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 10976447. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 10991932. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11012262. kelime, önceki kelime: '8.'.
# Cümle: 'gün' 11020779. kelime, önceki kelime: '15'.
# Cümle: 'gün' 11020782. kelime, önceki kelime: '15'.
# Cümle: 'gün' 11034154. kelime, önceki kelime: '152'.
# Cümle: 'gün' 11034176. kelime, önceki kelime: '127'.
# Cümle: 'gün' 11034197. kelime, önceki kelime: '74'.
# Cümle: 'gün' 11034244. kelime, önceki kelime: '288'.
# Cümle: 'gün' 11034268. kelime, önceki kelime: '21'.
# Cümle: 'gün' 11034288. kelime, önceki kelime: '145'.
# Cümle: 'gün' 11034312. kelime, önceki kelime: '349'.
# Cümle: 'gün' 11034336. kelime, önceki kelime: '38'.
# Cümle: 'gün' 11034355. kelime, önceki kelime: '241'.
# Cümle: 'gün' 11034370. kelime, önceki kelime: '237'.
# Cümle: 'gün' 11066832. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11066895. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 11067376. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11068384. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 11068418. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11068886. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 11072858. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11090933. kelime, önceki kelime: 'ticaretin'.
# Cümle: 'gün' 11110650. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11111376. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11111649. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11111681. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 11127275. kelime, önceki kelime: '454'.
# Cümle: 'gün' 11149247. kelime, önceki kelime: '12'.
# Cümle: 'gün' 11155822. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11170544. kelime, önceki kelime: '13'.
# Cümle: 'gün' 11171401. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11174484. kelime, önceki kelime: '"her'.
# Cümle: 'gün' 11174975. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11176009. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11181300. kelime, önceki kelime: '3'.
# Cümle: 'gün' 11183001. kelime, önceki kelime: '189'.
# Cümle: 'gün' 11183019. kelime, önceki kelime: '69'.
# Cümle: 'gün' 11183031. kelime, önceki kelime: '4'.
# Cümle: 'gün' 11183044. kelime, önceki kelime: '28'.
# Cümle: 'gün' 11183061. kelime, önceki kelime: '8'.
# Cümle: 'gün' 11183074. kelime, önceki kelime: '101'.
# Cümle: 'gün' 11183091. kelime, önceki kelime: '28'.
# Cümle: 'gün' 11183103. kelime, önceki kelime: '74'.
# Cümle: 'gün' 11184632. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 11189012. kelime, önceki kelime: '28'.
# Cümle: 'gün' 11190131. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 11198928. kelime, önceki kelime: '365'.
# Cümle: 'gün' 11198932. kelime, önceki kelime: '365'.
# Cümle: 'gün' 11198969. kelime, önceki kelime: '365'.
# Cümle: 'gün' 11200658. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 11207045. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 11214207. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11214360. kelime, önceki kelime: 've'.
# Cümle: 'gün' 11218059. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 11218073. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11218894. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 11233714. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11239291. kelime, önceki kelime: 'yeni'.
# Cümle: 'gün' 11240310. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11248345. kelime, önceki kelime: '3'.
# Cümle: 'gün' 11248437. kelime, önceki kelime: '2'.
# Cümle: 'gün' 11261907. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11266241. kelime, önceki kelime: 'aydın'.
# Cümle: 'gün' 11279232. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 11287511. kelime, önceki kelime: 'uzun'.
# Cümle: 'gün' 11309625. kelime, önceki kelime: 'oynandığı'.
# Cümle: 'gün' 11315916. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11325744. kelime, önceki kelime: 'performansını'.
# Cümle: 'gün' 11330013. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11338591. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11347808. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11349495. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11349970. kelime, önceki kelime: '4'.
# Cümle: 'gün' 11350014. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11351034. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11361221. kelime, önceki kelime: 'parlak'.
# Cümle: 'gün' 11364683. kelime, önceki kelime: 'insanların'.
# Cümle: 'gün' 11372065. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 11389050. kelime, önceki kelime: '2-5'.
# Cümle: 'gün' 11389257. kelime, önceki kelime: '7'.
# Cümle: 'gün' 11419954. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11439421. kelime, önceki kelime: 'ardından'.
# Cümle: 'gün' 11448836. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 11469755. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11486464. kelime, önceki kelime: '231'.
# Cümle: 'gün' 11486714. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11490317. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11490415. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 11490431. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 11490522. kelime, önceki kelime: '2015-:'.
# Cümle: 'gün' 11491630. kelime, önceki kelime: '8.'.
# Cümle: 'gün' 11491727. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 11494460. kelime, önceki kelime: '1993-2011:'.
# Cümle: 'gün' 11494784. kelime, önceki kelime: '32.'.
# Cümle: 'gün' 11495536. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11498652. kelime, önceki kelime: 'bayram'.
# Cümle: 'gün' 11498791. kelime, önceki kelime: 'bu'.
# Cümle: 'gün' 11499204. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 11500624. kelime, önceki kelime: 'kutlandığı'.
# Cümle: 'gün' 11501193. kelime, önceki kelime: '3'.
# Cümle: 'gün' 11501219. kelime, önceki kelime: 'bu'.
# Cümle: 'gün' 11501834. kelime, önceki kelime: '4'.
# Cümle: 'gün' 11506172. kelime, önceki kelime: 'ürünler'.
# Cümle: 'gün' 11524169. kelime, önceki kelime: 'gelgit'.
# Cümle: 'gün' 11535550. kelime, önceki kelime: '1001'.
# Cümle: 'gün' 11541092. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11552529. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 11566642. kelime, önceki kelime: '8.'.
# Cümle: 'gün' 11567083. kelime, önceki kelime: '8.'.
# Cümle: 'gün' 11582217. kelime, önceki kelime: '(1513,6'.
# Cümle: 'gün' 11582231. kelime, önceki kelime: '/'.
# Cümle: 'gün' 11593407. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 11618759. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 11647798. kelime, önceki kelime: 'beytepe'.
# Cümle: 'gün' 11657759. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11659903. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 11661188. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11700649. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 11707811. kelime, önceki kelime: 'tam'.
# Cümle: 'gün' 11707834. kelime, önceki kelime: '4'.
# Cümle: 'gün' 11711684. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 11716780. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 11737657. kelime, önceki kelime: '42'.
# Cümle: 'gün' 11739413. kelime, önceki kelime: 'bakanı'.
# Cümle: 'gün' 11748509. kelime, önceki kelime: '/'.
# Cümle: 'gün' 11759620. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 11759717. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 11759845. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11759890. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 11768881. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 11768890. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 11769918. kelime, önceki kelime: 'öldürüldüğü'.
# Cümle: 'gün' 11774949. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11775948. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 11804591. kelime, önceki kelime: '85'.
# Cümle: 'gün' 11811963. kelime, önceki kelime: '231'.
# Cümle: 'gün' 11812213. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11818344. kelime, önceki kelime: 'buçuk'.
# Cümle: 'gün' 11830495. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11853735. kelime, önceki kelime: '12'.
# Cümle: 'gün' 11853752. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11901469. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 11902226. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 11902262. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 11903096. kelime, önceki kelime: '6'.
# Cümle: 'gün' 11905718. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 11917925. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11920682. kelime, önceki kelime: 'altmış'.
# Cümle: 'gün' 11933165. kelime, önceki kelime: '2'.
# Cümle: 'gün' 11939694. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 11940683. kelime, önceki kelime: '333'.
# Cümle: 'gün' 11940832. kelime, önceki kelime: '351'.
# Cümle: 'gün' 11940858. kelime, önceki kelime: '262'.
# Cümle: 'gün' 11944947. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11959082. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 11961162. kelime, önceki kelime: 'gelgit'.
# Cümle: 'gün' 11971535. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11973929. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 11983244. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 11993361. kelime, önceki kelime: '16'.
# Cümle: 'gün' 12014206. kelime, önceki kelime: 'öbür'.
# Cümle: 'gün' 12019421. kelime, önceki kelime: 'doğan'.
# Cümle: 'gün' 12026504. kelime, önceki kelime: '14'.
# Cümle: 'gün' 12081301. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 12091855. kelime, önceki kelime: 'mi?'.
# Cümle: 'gün' 12104198. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 12110590. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 12112109. kelime, önceki kelime: 'seviye'.
# Cümle: 'gün' 12113670. kelime, önceki kelime: '120'.
# Cümle: 'gün' 12124096. kelime, önceki kelime: 'kez'.
# Cümle: 'gün' 12124534. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 12178623. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 12203297. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12203687. kelime, önceki kelime: 'girdiği'.
# Cümle: 'gün' 12205583. kelime, önceki kelime: '6-7'.
# Cümle: 'gün' 12221805. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 12226518. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 12227857. kelime, önceki kelime: 'yeni'.
# Cümle: 'gün' 12229866. kelime, önceki kelime: 'tek'.
# Cümle: 'gün' 12230112. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 12230257. kelime, önceki kelime: '16'.
# Cümle: 'gün' 12230279. kelime, önceki kelime: '23'.
# Cümle: 'gün' 12236293. kelime, önceki kelime: 'yükselmiştir.'.
# Cümle: 'gün' 12236400. kelime, önceki kelime: 'yükseldi.'.
# Cümle: 'gün' 12236605. kelime, önceki kelime: 'yükselmiştir.'.
# Cümle: 'gün' 12236717. kelime, önceki kelime: 'yükselmiştir.'.
# Cümle: 'gün' 12236795. kelime, önceki kelime: 'yükselmiştir.'.
# Cümle: 'gün' 12236894. kelime, önceki kelime: 'yükselmiştir.'.
# Cümle: 'gün' 12240865. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 12261339. kelime, önceki kelime: 'sonlanma'.
# Cümle: 'gün' 12268823. kelime, önceki kelime: 'yapmadan'.
# Cümle: 'gün' 12292202. kelime, önceki kelime: '2'.
# Cümle: 'gün' 12292266. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12292360. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 12293494. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 12294901. kelime, önceki kelime: '28'.
# Cümle: 'gün' 12295168. kelime, önceki kelime: 've'.
# Cümle: 'gün' 12309736. kelime, önceki kelime: 'gösterileceği'.
# Cümle: 'gün' 12327401. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 12333026. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 12333918. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12342951. kelime, önceki kelime: '1.9'.
# Cümle: 'gün' 12351611. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12360571. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12360762. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12363097. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12367025. kelime, önceki kelime: '3'.
# Cümle: 'gün' 12367028. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 12367345. kelime, önceki kelime: '5'.
# Cümle: 'gün' 12367424. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 12367435. kelime, önceki kelime: '10'.
# Cümle: 'gün' 12368849. kelime, önceki kelime: '(2.063,2'.
# Cümle: 'gün' 12368862. kelime, önceki kelime: '/'.
# Cümle: 'gün' 12375317. kelime, önceki kelime: '1.'.
# Cümle: 'gün' 12375376. kelime, önceki kelime: '2.'.
# Cümle: 'gün' 12378407. kelime, önceki kelime: 'sonraki'.
# Cümle: 'gün' 12378665. kelime, önceki kelime: 'önceki'.
# Cümle: 'gün' 12396225. kelime, önceki kelime: '317'.
# Cümle: 'gün' 12445176. kelime, önceki kelime: 'aydın'.
# Cümle: 'gün' 12449763. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12450033. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12457465. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12468353. kelime, önceki kelime: '54'.
# Cümle: 'gün' 12480883. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12494687. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 12505628. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 12511349. kelime, önceki kelime: '10'.
# Cümle: 'gün' 12512314. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 12525964. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12532391. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 12545330. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 12552271. kelime, önceki kelime: 'arzularının'.
# Cümle: 'gün' 12553275. kelime, önceki kelime: '60'.
# Cümle: 'gün' 12564099. kelime, önceki kelime: 'uzun'.
# Cümle: 'gün' 12575153. kelime, önceki kelime: '75'.
# Cümle: 'gün' 12588244. kelime, önceki kelime: 've'.
# Cümle: 'gün' 12596575. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12597195. kelime, önceki kelime: '70'.
# Cümle: 'gün' 12598833. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12621651. kelime, önceki kelime: '/'.
# Cümle: 'gün' 12635357. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12637843. kelime, önceki kelime: 'güzel'.
# Cümle: 'gün' 12644755. kelime, önceki kelime: 'daha'.
# Cümle: 'gün' 12645653. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 12680278. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 12685822. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 12685882. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 12690895. kelime, önceki kelime: '1'.
# Cümle: 'gün' 12692631. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 12709874. kelime, önceki kelime: 'toplandığı'.
# Cümle: 'gün' 12742611. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 12742646. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 12742863. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12755282. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755311. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755316. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755337. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755343. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755368. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755395. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755432. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755441. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12755755. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 12770857. kelime, önceki kelime: 'zor'.
# Cümle: 'gün' 12786846. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12788674. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 12791077. kelime, önceki kelime: '7'.
# Cümle: 'gün' 12800921. kelime, önceki kelime: '315'.
# Cümle: 'gün' 12800947. kelime, önceki kelime: '203'.
# Cümle: 'gün' 12800972. kelime, önceki kelime: '178'.
# Cümle: 'gün' 12800996. kelime, önceki kelime: '46'.
# Cümle: 'gün' 12857183. kelime, önceki kelime: '5'.
# Cümle: 'gün' 12865057. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12869010. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 12871573. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 12905830. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 12909511. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 12918613. kelime, önceki kelime: '4'.
# Cümle: 'gün' 12920455. kelime, önceki kelime: '15'.
# Cümle: 'gün' 12925274. kelime, önceki kelime: 'periyodu'.
# Cümle: 'gün' 12937899. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 12973087. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 12973165. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 12976122. kelime, önceki kelime: 'alanları'.
# Cümle: 'gün' 12977550. kelime, önceki kelime: '30'.
# Cümle: 'gün' 12991763. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12991777. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 12991802. kelime, önceki kelime: '20'.
# Cümle: 'gün' 12992694. kelime, önceki kelime: 'yağmur'.
# Cümle: 'gün' 13011654. kelime, önceki kelime: 'hastalığı'.
# Cümle: 'gün' 13019016. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 13019529. kelime, önceki kelime: 'i̇zlenim:'.
# Cümle: 'gün' 13035635. kelime, önceki kelime: 'plajı'nda'.
# Cümle: 'gün' 13043838. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 13054631. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13072498. kelime, önceki kelime: '8'.
# Cümle: 'gün' 13072506. kelime, önceki kelime: '10'.
# Cümle: 'gün' 13149332. kelime, önceki kelime: 'yeni'.
# Cümle: 'gün' 13163563. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 13165339. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13165506. kelime, önceki kelime: 'kırk'.
# Cümle: 'gün' 13165513. kelime, önceki kelime: 'kırk'.
# Cümle: 'gün' 13165617. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 13166054. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13166264. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 13166268. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 13171405. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 13184376. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13197648. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13208411. kelime, önceki kelime: 'verdiği'.
# Cümle: 'gün' 13208500. kelime, önceki kelime: 'evlendiği'.
# Cümle: 'gün' 13220872. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 13221115. kelime, önceki kelime: '30'.
# Cümle: 'gün' 13221288. kelime, önceki kelime: '30'.
# Cümle: 'gün' 13221294. kelime, önceki kelime: '22'.
# Cümle: 'gün' 13223790. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13229625. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13229653. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13229660. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 13255453. kelime, önceki kelime: '15'.
# Cümle: 'gün' 13255456. kelime, önceki kelime: '15'.
# Cümle: 'gün' 13270027. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 13270032. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13270073. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 13270078. kelime, önceki kelime: '10'.
# Cümle: 'gün' 13274955. kelime, önceki kelime: 'ile'.
# Cümle: 'gün' 13282842. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 13283472. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 13283701. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 13290226. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13312141. kelime, önceki kelime: 'doğduğu'.
# Cümle: 'gün' 13315223. kelime, önceki kelime: 'bilgi'.
# Cümle: 'gün' 13323171. kelime, önceki kelime: '28'.
# Cümle: 'gün' 13334605. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13335093. kelime, önceki kelime: 'yayınlandığı'.
# Cümle: 'gün' 13355552. kelime, önceki kelime: '34'.
# Cümle: 'gün' 13373871. kelime, önceki kelime: '2'.
# Cümle: 'gün' 13390647. kelime, önceki kelime: 'bölgesinde'.
# Cümle: 'gün' 13436296. kelime, önceki kelime: 'olduğu'.
# Cümle: 'gün' 13446774. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 13446955. kelime, önceki kelime: 'atandığı'.
# Cümle: 'gün' 13464607. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 13465121. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 13476952. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 13492063. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 13505253. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 13505480. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 13539658. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 13576726. kelime, önceki kelime: '50'.
# Cümle: 'gün' 13592692. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 13595131. kelime, önceki kelime: '360'.
# Cümle: 'gün' 13597754. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 13603531. kelime, önceki kelime: '2'.
# Cümle: 'gün' 13635948. kelime, önceki kelime: 'yılında'.
# Cümle: 'gün' 13638638. kelime, önceki kelime: '2011:'.
# Cümle: 'gün' 13685000. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 13691081. kelime, önceki kelime: 'durumu'.
# Cümle: 'gün' 13691397. kelime, önceki kelime: 'tugay'.
# Cümle: 'gün' 13691478. kelime, önceki kelime: 'planında'.
# Cümle: 'gün' 13691501. kelime, önceki kelime: 'raporlarda,'.
# Cümle: 'gün' 13692150. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 13692258. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 13692265. kelime, önceki kelime: 'ilk'.
# Cümle: 'gün' 13696217. kelime, önceki kelime: 'güngör'.
# Cümle: 'gün' 13696856. kelime, önceki kelime: '35'.
# Cümle: 'gün' 13700055. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13704160. kelime, önceki kelime: '231'.
# Cümle: 'gün' 13704410. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 13713483. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 13724073. kelime, önceki kelime: 'açık'.
# Cümle: 'gün' 13724078. kelime, önceki kelime: 'açık'.
# Cümle: 'gün' 13724082. kelime, önceki kelime: 'kapalı'.
# Cümle: 'gün' 13725091. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 13728611. kelime, önceki kelime: '•'.
# Cümle: 'gün' 13770621. kelime, önceki kelime: '45'.
# Cümle: 'gün' 13777565. kelime, önceki kelime: 'parlak'.
# Cümle: 'gün' 13787657. kelime, önceki kelime: 'hangi'.
# Cümle: 'gün' 13793280. kelime, önceki kelime: '28'.
# Cümle: 'gün' 13794172. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13801559. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13806364. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 13825490. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 13830033. kelime, önceki kelime: '20'.
# Cümle: 'gün' 13840863. kelime, önceki kelime: 'batan'.
# Cümle: 'gün' 13842810. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13870421. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13879660. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 13882507. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 13888026. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 13889673. kelime, önceki kelime: '27'.
# Cümle: 'gün' 13901305. kelime, önceki kelime: '(49'.
# Cümle: 'gün' 13920323. kelime, önceki kelime: 'yayınlandığı'.
# Cümle: 'gün' 13928443. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 13941043. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 13943400. kelime, önceki kelime: '2'.
# Cümle: 'gün' 13944783. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 13975658. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 13979096. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 13979112. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 13979267. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 13979461. kelime, önceki kelime: '28'.
# Cümle: 'gün' 13984214. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 13984217. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 13988339. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14000375. kelime, önceki kelime: 'giderir.'.
# Cümle: 'gün' 14012643. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14027655. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14027665. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14028223. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14033191. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 14039405. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14056427. kelime, önceki kelime: 'yıl'.
# Cümle: 'gün' 14056487. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14056548. kelime, önceki kelime: 'yıl'.
# Cümle: 'gün' 14062920. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 14069805. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14079271. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14082097. kelime, önceki kelime: '357'.
# Cümle: 'gün' 14086838. kelime, önceki kelime: 'ayrıca'.
# Cümle: 'gün' 14086954. kelime, önceki kelime: 'geldiği'.
# Cümle: 'gün' 14091354. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 14093019. kelime, önceki kelime: '15'.
# Cümle: 'gün' 14096265. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 14097319. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 14126135. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14132363. kelime, önceki kelime: '31'.
# Cümle: 'gün' 14133686. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 14134061. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14134360. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14146715. kelime, önceki kelime: '42'.
# Cümle: 'gün' 14147017. kelime, önceki kelime: '4'.
# Cümle: 'gün' 14148106. kelime, önceki kelime: 'köprüsü'.
# Cümle: 'gün' 14156134. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 14156151. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14159460. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 14173199. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 14195161. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 14215104. kelime, önceki kelime: '·'.
# Cümle: 'gün' 14292142. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 14301488. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 14311625. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 14326655. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14327283. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 14327366. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14327470. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 14327534. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 14327603. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 14336232. kelime, önceki kelime: 'gümüşçünler'.
# Cümle: 'gün' 14352110. kelime, önceki kelime: '303'.
# Cümle: 'gün' 14352913. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 14366644. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 14391930. kelime, önceki kelime: '40'.
# Cümle: 'gün' 14391946. kelime, önceki kelime: '40'.
# Cümle: 'gün' 14393405. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 14393431. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14393819. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14393830. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 14393848. kelime, önceki kelime: 'önceki'.
# Cümle: 'gün' 14393893. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14393929. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14393957. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14413807. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14417250. kelime, önceki kelime: 'mehmet'.
# Cümle: 'gün' 14419014. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 14433722. kelime, önceki kelime: 'tam'.
# Cümle: 'gün' 14462765. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 14483021. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 14489698. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 14497093. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 14514358. kelime, önceki kelime: 'tek'.
# Cümle: 'gün' 14524621. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 14534506. kelime, önceki kelime: 'ali'.
# Cümle: 'gün' 14547924. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14547991. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14576779. kelime, önceki kelime: '(28'.
# Cümle: 'gün' 14582788. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 14593257. kelime, önceki kelime: '112'.
# Cümle: 'gün' 14596974. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 14615649. kelime, önceki kelime: 'yılında'.
# Cümle: 'gün' 14631862. kelime, önceki kelime: '"üçüncü'.
# Cümle: 'gün' 14633082. kelime, önceki kelime: 'dokuz'.
# Cümle: 'gün' 14653509. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14653685. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 14653825. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 14675371. kelime, önceki kelime: '373'.
# Cümle: 'gün' 14681981. kelime, önceki kelime: 'ay,'.
# Cümle: 'gün' 14697181. kelime, önceki kelime: '1-2'.
# Cümle: 'gün' 14697278. kelime, önceki kelime: '2-3'.
# Cümle: 'gün' 14698692. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 14699041. kelime, önceki kelime: '40'.
# Cümle: 'gün' 14699216. kelime, önceki kelime: '1-3'.
# Cümle: 'gün' 14699636. kelime, önceki kelime: '1-3'.
# Cümle: 'gün' 14737351. kelime, önceki kelime: ','.
# Cümle: 'gün' 14739051. kelime, önceki kelime: '4'.
# Cümle: 'gün' 14744474. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14749093. kelime, önceki kelime: 'son'.
# Cümle: 'gün' 14760889. kelime, önceki kelime: ']'.
# Cümle: 'gün' 14764468. kelime, önceki kelime: 'yıl'.
# Cümle: 'gün' 14764524. kelime, önceki kelime: 'yıl'.
# Cümle: 'gün' 14767021. kelime, önceki kelime: 'yıl'.
# Cümle: 'gün' 14777382. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14789036. kelime, önceki kelime: 'gelgit'.
# Cümle: 'gün' 14793107. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 14794398. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 14794403. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 14794710. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 14804152. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 14804830. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 14811725. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 14813909. kelime, önceki kelime: 'sekiz'.
# Cümle: 'gün' 14817945. kelime, önceki kelime: 'gibi,'.
# Cümle: 'gün' 14835926. kelime, önceki kelime: 'birkaç'.
# ...
# Cümle: 'gün' 35874861. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 35881469. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 35889394. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 35902953. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 35906133. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 35924955. kelime, önceki kelime: 'açık'.
# Cümle: 'gün' 35924960. kelime, önceki kelime: 'açık'.
# Cümle: 'gün' 35924964. kelime, önceki kelime: 'kapalı'.
# Cümle: 'gün' 35925973. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 35935978. kelime, önceki kelime: '50'.
# Cümle: 'gün' 35947848. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 35948293. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 35948761. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 35961957. kelime, önceki kelime: 'geçen'.
# Cümle: 'gün' 35962272. kelime, önceki kelime: 'geçen'.
# Cümle: 'gün' 35963751. kelime, önceki kelime: 'değerler'.
# Cümle: 'gün' 35964955. kelime, önceki kelime: 'önemli'.
# Cümle: 'gün' 35976868. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 35980098. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 35980142. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 35980156. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 35985132. kelime, önceki kelime: '15'.
# Cümle: 'gün' 35985135. kelime, önceki kelime: '15'.
# Cümle: 'gün' 36022356. kelime, önceki kelime: 'kaçırıldığı'.
# Cümle: 'gün' 36050278. kelime, önceki kelime: '5'.
# Cümle: 'gün' 36063228. kelime, önceki kelime: 'edildiği'.
# Cümle: 'gün' 36081629. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36126037. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 36140778. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36144104. kelime, önceki kelime: '18'.
# Cümle: 'gün' 36144119. kelime, önceki kelime: '9'.
# Cümle: 'gün' 36149556. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 36158442. kelime, önceki kelime: 'sırlarını'.
# Cümle: 'gün' 36186781. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36191601. kelime, önceki kelime: 'hazırlandığı'.
# Cümle: 'gün' 36200407. kelime, önceki kelime: 'yahudi'.
# Cümle: 'gün' 36204004. kelime, önceki kelime: '5'.
# Cümle: 'gün' 36215915. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 36220080. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36256768. kelime, önceki kelime: 'aydın'.
# Cümle: 'gün' 36257275. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36263980. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 36268272. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36271198. kelime, önceki kelime: 'sekiz'.
# Cümle: 'gün' 36279320. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 36286615. kelime, önceki kelime: '27'.
# Cümle: 'gün' 36303773. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36312001. kelime, önceki kelime: '"bu'.
# Cümle: 'gün' 36323915. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36343715. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 36345637. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 36346443. kelime, önceki kelime: '"o'.
# Cümle: 'gün' 36346564. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36351222. kelime, önceki kelime: 'on'.
# Cümle: 'gün' 36351383. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 36351807. kelime, önceki kelime: '18'.
# Cümle: 'gün' 36351849. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36352658. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 36352724. kelime, önceki kelime: 'saldırıldı.'.
# Cümle: 'gün' 36353228. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 36353506. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 36353631. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36353690. kelime, önceki kelime: 'önceki'.
# Cümle: 'gün' 36354489. kelime, önceki kelime: 'önceki'.
# Cümle: 'gün' 36354639. kelime, önceki kelime: 'sonraki'.
# Cümle: 'gün' 36356002. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 36356079. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36359252. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 36365408. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36365603. kelime, önceki kelime: '“o'.
# Cümle: 'gün' 36378445. kelime, önceki kelime: '12'.
# Cümle: 'gün' 36378728. kelime, önceki kelime: '12'.
# Cümle: 'gün' 36387880. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36393572. kelime, önceki kelime: '7'.
# Cümle: 'gün' 36418716. kelime, önceki kelime: 'önceki'.
# Cümle: 'gün' 36436741. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 36436840. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 36450757. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36450762. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36454937. kelime, önceki kelime: 'mahkeme'.
# Cümle: 'gün' 36455171. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36491528. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 36493490. kelime, önceki kelime: '20'.
# Cümle: 'gün' 36494645. kelime, önceki kelime: 've'.
# Cümle: 'gün' 36495872. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36495893. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36496048. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36496069. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 36497209. kelime, önceki kelime: '12'.
# Cümle: 'gün' 36497627. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36499599. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36500635. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 36501369. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 36502761. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 36503283. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 36503911. kelime, önceki kelime: 'yarım'.
# Cümle: 'gün' 36504229. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36504951. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36506241. kelime, önceki kelime: '8'.
# Cümle: 'gün' 36526657. kelime, önceki kelime: 'mehmet'.
# Cümle: 'gün' 36533220. kelime, önceki kelime: 'trenler'.
# Cümle: 'gün' 36544524. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 36544540. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36579684. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36611835. kelime, önceki kelime: 'bütün'.
# Cümle: 'gün' 36613554. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36616168. kelime, önceki kelime: 'kez'.
# Cümle: 'gün' 36616606. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 36624334. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36643258. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36648388. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 36654810. kelime, önceki kelime: 'küçük'.
# Cümle: 'gün' 36658238. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36658253. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36667738. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36679281. kelime, önceki kelime: '30-35'.
# Cümle: 'gün' 36687965. kelime, önceki kelime: 'güneşli'.
# Cümle: 'gün' 36693795. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 36693902. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 36695489. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36722480. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 36736502. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 36737496. kelime, önceki kelime: 'beş'.
# Cümle: 'gün' 36757237. kelime, önceki kelime: 'doğduğu'.
# Cümle: 'gün' 36759321. kelime, önceki kelime: '21'.
# Cümle: 'gün' 36761623. kelime, önceki kelime: 'altıncı'.
# Cümle: 'gün' 36765990. kelime, önceki kelime: 'bütün'.
# Cümle: 'gün' 36778501. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36778677. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 36779040. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36779649. kelime, önceki kelime: 'sonraki'.
# Cümle: 'gün' 36779691. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36779952. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 36780058. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 36780474. kelime, önceki kelime: '35'.
# Cümle: 'gün' 36780844. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 36780931. kelime, önceki kelime: 'öbür'.
# Cümle: 'gün' 36791827. kelime, önceki kelime: '12'.
# Cümle: 'gün' 36795226. kelime, önceki kelime: 'mehmet'.
# Cümle: 'gün' 36798382. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 36798528. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36815629. kelime, önceki kelime: 'evlendiğin'.
# Cümle: 'gün' 36826269. kelime, önceki kelime: '12'.
# Cümle: 'gün' 36873021. kelime, önceki kelime: ').'.
# Cümle: 'gün' 36878614. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 36886001. kelime, önceki kelime: '10'.
# Cümle: 'gün' 36886208. kelime, önceki kelime: '3'.
# Cümle: 'gün' 36917044. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 36943693. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 36944907. kelime, önceki kelime: '2041,056'.
# Cümle: 'gün' 36959915. kelime, önceki kelime: '3'.
# Cümle: 'gün' 36960201. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 36962038. kelime, önceki kelime: '300'.
# Cümle: 'gün' 36962231. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 37025923. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37029465. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 37030731. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 37030802. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 37044913. kelime, önceki kelime: 'gəldiyi'.
# Cümle: 'gün' 37045996. kelime, önceki kelime: '343'.
# Cümle: 'gün' 37046805. kelime, önceki kelime: '10'.
# Cümle: 'gün' 37053874. kelime, önceki kelime: '3'.
# Cümle: 'gün' 37054000. kelime, önceki kelime: 'yapılan'.
# Cümle: 'gün' 37056137. kelime, önceki kelime: 'berktay'.
# Cümle: 'gün' 37074575. kelime, önceki kelime: '10'.
# Cümle: 'gün' 37078691. kelime, önceki kelime: '25'.
# Cümle: 'gün' 37078734. kelime, önceki kelime: '1'.
# Cümle: 'gün' 37097289. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 37098222. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37098434. kelime, önceki kelime: '5'.
# Cümle: 'gün' 37100955. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37148671. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37154868. kelime, önceki kelime: '/'.
# Cümle: 'gün' 37202474. kelime, önceki kelime: 'mehmet'.
# Cümle: 'gün' 37237693. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 37237780. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 37238813. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 37245501. kelime, önceki kelime: ')'.
# Cümle: 'gün' 37262011. kelime, önceki kelime: '7'.
# Cümle: 'gün' 37263920. kelime, önceki kelime: 'sonraki'.
# Cümle: 'gün' 37263969. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37278524. kelime, önceki kelime: 'sonraki'.
# Cümle: 'gün' 37294998. kelime, önceki kelime: '4.celal'.
# Cümle: 'gün' 37314241. kelime, önceki kelime: 'geçen'.
# Cümle: 'gün' 37328607. kelime, önceki kelime: 'sonraki'.
# Cümle: 'gün' 37348709. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 37361150. kelime, önceki kelime: '4'.
# Cümle: 'gün' 37361889. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 37362441. kelime, önceki kelime: '312'.
# Cümle: 'gün' 37390118. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 37390220. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37392581. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 37398810. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 37404960. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37414374. kelime, önceki kelime: 'yüz'.
# Cümle: 'gün' 37428320. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 37436606. kelime, önceki kelime: '213'.
# Cümle: 'gün' 37467750. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 37471526. kelime, önceki kelime: '20.000'.
# Cümle: 'gün' 37471580. kelime, önceki kelime: '20.000'.
# Cümle: 'gün' 37476723. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 37482098. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 37482478. kelime, önceki kelime: 'i̇ki'.
# Cümle: 'gün' 37482965. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 37483578. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 37484019. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 37495561. kelime, önceki kelime: 'da'.
# Cümle: 'gün' 37508265. kelime, önceki kelime: 'her'.
# Cümle: 'gün' 37514780. kelime, önceki kelime: '2'.
# Cümle: 'gün' 37527552. kelime, önceki kelime: 'dört'.
# Cümle: 'gün' 37531981. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37532043. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37533297. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37534495. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37550085. kelime, önceki kelime: '(38'.
# Cümle: 'gün' 37552773. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37564069. kelime, önceki kelime: 'yedinci'.
# Cümle: 'gün' 37566586. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 37589543. kelime, önceki kelime: 'başarılarını'.
# Cümle: 'gün' 37598385. kelime, önceki kelime: 'mezalimler'.
# Cümle: 'gün' 37605417. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 37617216. kelime, önceki kelime: 'televizyonlarda'.
# Cümle: 'gün' 37626692. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 37626825. kelime, önceki kelime: '18'.
# Cümle: 'gün' 37627240. kelime, önceki kelime: '3'.
# Cümle: 'gün' 37628107. kelime, önceki kelime: '9'.
# Cümle: 'gün' 37628133. kelime, önceki kelime: '16'.
# Cümle: 'gün' 37630387. kelime, önceki kelime: '33'.
# Cümle: 'gün' 37630550. kelime, önceki kelime: '2'.
# Cümle: 'gün' 37631777. kelime, önceki kelime: '45'.
# Cümle: 'gün' 37631887. kelime, önceki kelime: '10'.
# Cümle: 'gün' 37631896. kelime, önceki kelime: '45'.
# Cümle: 'gün' 37631958. kelime, önceki kelime: '15'.
# Cümle: 'gün' 37631976. kelime, önceki kelime: '15'.
# Cümle: 'gün' 37632012. kelime, önceki kelime: '3'.
# Cümle: 'gün' 37632166. kelime, önceki kelime: '3'.
# Cümle: 'gün' 37633459. kelime, önceki kelime: '11'.
# Cümle: 'gün' 37633497. kelime, önceki kelime: '32'.
# Cümle: 'gün' 37633557. kelime, önceki kelime: '9'.
# Cümle: 'gün' 37654933. kelime, önceki kelime: 'altı'.
# Cümle: 'gün' 37660384. kelime, önceki kelime: '4'.
# Cümle: 'gün' 37694700. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37697278. kelime, önceki kelime: 'başlarında'.
# Cümle: 'gün' 37701469. kelime, önceki kelime: 'birkaç'.
# Cümle: 'gün' 37701810. kelime, önceki kelime: '1-10'.
# Cümle: 'gün' 37703181. kelime, önceki kelime: 'öbür'.
# Cümle: 'gün' 37725474. kelime, önceki kelime: '20'.
# Cümle: 'gün' 37725534. kelime, önceki kelime: '15-20'.
# Cümle: 'gün' 37748133. kelime, önceki kelime: '21'.
# Cümle: 'gün' 37754599. kelime, önceki kelime: '140'.
# Cümle: 'gün' 37755292. kelime, önceki kelime: 'yaşından'.
# Cümle: 'gün' 37765018. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37784574. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 37785188. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 37796416. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37796693. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37796916. kelime, önceki kelime: 'iki'.
# Cümle: 'gün' 37825563. kelime, önceki kelime: '1-2'.
# Cümle: 'gün' 37825584. kelime, önceki kelime: '5-7'.
# Cümle: 'gün' 37825634. kelime, önceki kelime: 'bir-iki'.
# Cümle: 'gün' 37825666. kelime, önceki kelime: 'beş-yedi'.
# Cümle: 'gün' 37835911. kelime, önceki kelime: 'o'.
# Cümle: 'gün' 37847494. kelime, önceki kelime: 'han'.
# Cümle: 'gün' 37869560. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37885982. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37918399. kelime, önceki kelime: 'bir'.
# Cümle: 'gün' 37929019. kelime, önceki kelime: '1.'.
# Cümle: 'gün' 37929438. kelime, önceki kelime: '2.'.
# Cümle: 'gün' 37929823. kelime, önceki kelime: '3.'.
# Cümle: 'gün' 37930234. kelime, önceki kelime: '4.'.
# Cümle: 'gün' 37930677. kelime, önceki kelime: '5.'.
# Cümle: 'gün' 37931206. kelime, önceki kelime: '6.'.
# Cümle: 'gün' 37931700. kelime, önceki kelime: '7.'.
# Cümle: 'gün' 37932178. kelime, önceki kelime: '8.'.
# Cümle: 'gün' 37932632. kelime, önceki kelime: '9.'.
# Cümle: 'gün' 37933022. kelime, önceki kelime: '10.'.
# Cümle: 'gün' 37933305. kelime, önceki kelime: '11.'.
# Cümle: 'gün' 37933525. kelime, önceki kelime: '12.'.
# Cümle: 'gün' 37933725. kelime, önceki kelime: '13.'.
# Cümle: 'gün' 37933856. kelime, önceki kelime: '14.'.
# Cümle: 'gün' 37936224. kelime, önceki kelime: '20'.
# Cümle: 'gün' 37946359. kelime, önceki kelime: 'üç'.
# Cümle: 'gün' 37946478. kelime, önceki kelime: 'yedi'.
# Cümle: 'gün' 37971654. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37983440. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37983589. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37991428. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37991489. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37991668. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37991901. kelime, önceki kelime: 'aynı'.
# Cümle: 'gün' 37992073. kelime, önceki kelime: '14'.
# Cümle: 'gün' 37998126. kelime, önceki kelime: 'geçen'.
# Cümle: 'gün' 38043905. kelime, önceki kelime: '/'.
# Cümle: 'gün' 38047822. kelime, önceki kelime: 'ertesi'.
# Cümle: 'gün' 38052819. kelime, önceki kelime: 'i̇lk'.
# Cümle: 'gün' 38054392. kelime, önceki kelime: 'i̇lk'.
# --------------------------------------------------
