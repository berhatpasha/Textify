# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#data = pd.read_excel('resmiyet.xlsx')
# data = pd.read_excel('resmiyetV2.xlsx')
data = pd.read_excel('resmiyetV2.xlsx')

# %%
data.head(5)
# Out:
#                                          Cümle  Resmiyet
# 0                 Toplantı saati değiştirildi.        10
# 1              Size nasıl yardımcı olabilirim?         8
# 2  Görüşme planlarımızı netleştirebilir miyiz?        10
# 3    Lütfen bana detayları iletebilir misiniz?         7
# 4   Şirket politikası gereği bunu yapamıyoruz.        10

# %%
vector = TfidfVectorizer()
x = vector.fit_transform(data['Cümle'])
y = data["Resmiyet"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
simulator = model.predict(x_test)

# %%
print(mean_squared_error(y_test,simulator))
model.score(x_test,y_test)
# Out:
# 0.9946861146179033
# 0.8837530741708295

# %%
model.predict(vector.transform(["Projeyi tamamladınız mı?"]))
# Out:
# array([5.22966655])

# %%
model.predict(vector.transform(["Merhaba, nasıl olduğunuzdan eminim ama bu hafta biraz daha yoğun olacağım. Eğer uygun görürseniz, bu hafta sonu bir araya gelip daha detaylı bir şekilde konuşabiliriz. Ne zaman müsait olursanız, haber verirseniz sevinirim."]))
# Out:
# array([4.96302841])

# %%
model.predict(vector.transform(['Sayın yetkili, başvurunuz değerlendirmeye alınmıştır.']))
# Out:
# array([5.58703051])

# %%
model.predict(vector.transform(['Sayın Müşterimiz, başvurunuz tarafımıza ulaşmış olup, ilgili birim tarafından detaylı olarak incelendikten sonra en kısa sürede tarafınıza geri dönüş sağlanacaktır. İlginiz için teşekkür ederiz.']))
# Out:
# array([7.71116058])

# %%
model.predict(vector.transform(['']))
# Out:
# array([5.58703051])

# %%
print(mean_squared_error(y_test,simulator))
# Out:
# 0.9946861146179033

# %%
model.coef_
# Out:
# array([-1.05146385,  1.45648402, -1.65858122,  0.40292624, -2.52837763,
#        -1.40923098,  1.0421634 ,  2.01451411, -2.06760231,  1.28552442,
#        -1.62829033,  0.40292624, -0.16285596, -1.43027726, -1.5907511 ,
#        -2.53353857, -0.08668214, -0.4691511 , -1.31340796, -0.43117859,
#        -0.95447912,  1.71056535, -1.91903269,  1.0421634 ,  1.45648402,
#         1.13771716,  1.50818934,  1.13771716,  1.43360166,  1.70486813,
#         1.38698524,  1.69166901, -1.91903269,  1.38698524,  1.55194791,
#        -0.87953626, -1.40923098,  1.71056535,  1.45648402, -1.77776811,
#        -1.65858122, -0.95447912,  1.57873393,  1.45648402, -1.65681578,
#        -2.53353857,  1.38698524, -2.02686858, -0.92498986, -2.06760231,
#         1.0421634 ,  1.71056535,  0.70462781, -1.77776811, -0.95447912,
#        -1.77776811, -1.40923098, -2.54243254,  0.40292624, -1.40923098,
#         1.71056535, -0.95447912,  1.0421634 , -0.95447912, -1.05146385,
#        -1.77776811,  0.40292624,  2.66341185,  0.84224891, -0.35736396,
#        -2.54243254, -2.52837763,  1.14655982, -0.08668214,  1.57873393,
#        -1.43136159,  1.14655982,  0.35469429,  1.28552442,  1.15008085,
#         1.57873393, -0.35736396,  1.55194791,  1.28552442,  1.38698524,
#         1.43360166,  1.38698524,  0.35469429,  1.50818934,  1.69166901,
#         0.35469429, -1.65858122,  2.01366779,  1.70486813,  2.01451411,
#        -1.43136159,  1.28552442, -1.31340796,  1.13771716, -1.05146385,
#         1.28552442,  1.43360166,  1.70486813,  2.11351628,  1.69166901,
#         1.15008085,  1.38698524,  0.69649144,  1.13771716, -1.43136159,
#        -0.16285596,  1.13771716,  1.55194791,  1.14655982,  0.69649144,
#        -2.02686858, -1.31340796, -1.05146385, -0.87953626, -0.08668214,
#        -1.91903269, -3.07558365,  2.01451411, -1.31340796, -1.40923098,
#         1.55194791])

# %%
futures = vector.get_feature_names_out()
vector.get_feature_names_out()
# Out:
# array(['aldım', 'anlaşmanın', 'arkadaşlarla', 'açabilir', 'aşkım',
#        'bakmayın', 'bana', 'başlatılmıştır', 'beklemiyordum', 'belli',
#        'bir', 'biraz', 'birlikte', 'bu', 'bugün', 'buluşalım',
#        'buluşuyoruz', 'bunu', 'böyle', 'daha', 'defa', 'departmanla',
#        'ders', 'detayları', 'detaylarını', 'değerlendireceğim',
#        'değiştirildi', 'dönüş', 'edebilir', 'ederim', 'edilmesi',
#        'erkenden', 'gerekiyor', 'gerekmektedir', 'gereği', 'gerçekten',
#        'geç', 'geçildi', 'geçireceğim', 'gidelim', 'gittik', 'gördüm',
#        'görüşme', 'gözden', 'güzel', 'hadi', 'hareket', 'harikaydı',
#        'hava', 'hiç', 'iletebilir', 'iletişime', 'için', 'içmeye',
#        'kadar', 'kahve', 'kaldım', 'kanka', 'konuyu', 'kusura', 'lgili',
#        'lk', 'lütfen', 'manzara', 'memnunum', 'mi', 'misin', 'misiniz',
#        'miyiz', 'mı', 'napıyon', 'napıyosun', 'nasıl', 'ne',
#        'netleştirebilir', 'of', 'olabilirim', 'olacaktı', 'oldu',
#        'paylaşabilir', 'planlarımızı', 'planın', 'politikası', 'proje',
#        'prosedürlere', 'randevunuzu', 'resmî', 'ricam', 'saati', 'sabah',
#        'senden', 'sinemaya', 'size', 'sunum', 'süreciniz', 'sıkıldım',
#        'tarihi', 'tatlı', 'teklifinizi', 'telefon', 'teslim', 'teyit',
#        'teşekkür', 'toplantı', 'toplantımız', 'tutanaklarını', 'uygun',
#        'var', 've', 'ya', 'yapabilir', 'yapacağım', 'yapamıyoruz',
#        'yardımcı', 'yarın', 'yemek', 'yememiştim', 'yeni', 'yoruldum',
#        'zaman', 'çalışmam', 'çok', 'ödeme', 'önce', 'şe', 'şirket'],
#       dtype=object)

# %%
### önerme algoritması



with open('database', "r") as file:
    text = file.read()

words = text.lower().split()

def newWord(search_phrase):
    search_words = search_phrase.split()


    for start in range(len(search_words)):
        sub_phrase = search_words[start:]
        sub_length = len(sub_phrase)

        for i in range(len(words) - sub_length + 1):
            if words[i:i + sub_length] == sub_phrase:
                next_word = words[i + sub_length] if i + sub_length < len(words) else None
                position = i + 1
                print(f"Cümle: '{' '.join(sub_phrase)}' {position}. kelime, bir sonraki kelime: '{next_word}'." if next_word else f"Cümle: '{' '.join(sub_phrase)}' {position}. kelime, bir sonraki kelime: Yok.")

        print("-" * 50)

# %%
##
## indirgeme modülü

from difflib import get_close_matches

def reWrite(cumle, futures, esik=0.85):
    kelimeler = cumle.split()
    duzeltilmis_kelimeler = []

    for kelime in kelimeler:
        yakin_kelimeler = get_close_matches(kelime, futures, n=1, cutoff=esik)
        if yakin_kelimeler:
            duzeltilmis_kelimeler.append(yakin_kelimeler[0])
        else:
            duzeltilmis_kelimeler.append(kelime)

    return " ".join(duzeltilmis_kelimeler)



# Örnek cümle
cumle = "merhava arkadaşlar"

# Çalıştır
duzgun_cumle = reWrite(cumle, futures)
print(duzgun_cumle)
# Out:
# merhava arkadaşlarla

# %%
 while True:
    search_phrase = input("Cümle: ").strip()
    search_words = search_phrase.split()

    temp = 0
    for word in search_words:
      temp += model.predict(vector.transform([reWrite(word, futures)]))
      print(temp)

    ort = temp / len(search_words) # cümledeki kelimelerin ortalama ağırlık değeri
    print(f"ortalama ağırlık değeri = {ort}")

    print("Cümle taranıyor...")
    for word in search_words:
      if abs(model.predict(vector.transform([reWrite(word, futures)])) - ort) >= 1:
        print(f"yakalanan kelime >> '{word}'")
        InputSet = " ".join(search_words[:search_words.index(word)]) # algoritmaya girecek kısım
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-5c3e479b914e> in <cell line: 0>()
#       1 while True:
# ----> 2    search_phrase = input("Cümle: ").strip()
#       3    search_words = search_phrase.split()
#       4
#       5    temp = 0
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
### TEST MODÜLÜ

newWord("bir gün")
# Out:
# Streaming output truncated to the last 5000 lines.
# Cümle: 'gün' 8746866. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746876. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746890. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746906. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746934. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746946. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8746957. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746965. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8746977. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8746989. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747001. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747009. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747018. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747026. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747037. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747060. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747076. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747087. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747101. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747130. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747147. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747155. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747177. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747193. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747203. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747215. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747223. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747231. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747242. kelime, bir sonraki kelime: '/'.
# Cümle: 'gün' 8747271. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747531. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747537. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747545. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747577. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747608. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747616. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747633. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747653. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747661. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747678. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747686. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747694. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747702. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747728. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747749. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747774. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747783. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747797. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747807. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747820. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747828. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747849. kelime, bir sonraki kelime: 'ücretsiz'.
# Cümle: 'gün' 8747862. kelime, bir sonraki kelime: '100'.
# Cümle: 'gün' 8747873. kelime, bir sonraki kelime: 'us$'.
# Cümle: 'gün' 8747882. kelime, bir sonraki kelime: 'n/a'.
# Cümle: 'gün' 8747913. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747921. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747932. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8747958. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 8752380. kelime, bir sonraki kelime: 'ara'.
# Cümle: 'gün' 8767137. kelime, bir sonraki kelime: 'karısı'.
# Cümle: 'gün' 8767329. kelime, bir sonraki kelime: 'düşündükten'.
# Cümle: 'gün' 8779045. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 8784617. kelime, bir sonraki kelime: 'abhazya'.
# Cümle: 'gün' 8784634. kelime, bir sonraki kelime: 'abhazya'.
# Cümle: 'gün' 8784650. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 8784688. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 8784709. kelime, bir sonraki kelime: 'birleşik'.
# Cümle: 'gün' 8784732. kelime, bir sonraki kelime: 'aitaira'.
# Cümle: 'gün' 8784751. kelime, bir sonraki kelime: 'aitaira'.
# Cümle: 'gün' 8784769. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 8784788. kelime, bir sonraki kelime: 'ambf'.
# Cümle: 'gün' 8784810. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 8784829. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 8784845. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 8794123. kelime, bir sonraki kelime: '(1965)'.
# Cümle: 'gün' 8794185. kelime, bir sonraki kelime: '(1971)'.
# Cümle: 'gün' 8808907. kelime, bir sonraki kelime: 'zileli'.
# Cümle: 'gün' 8808919. kelime, bir sonraki kelime: 'yaşanacak'.
# Cümle: 'gün' 8895966. kelime, bir sonraki kelime: '(1955)'.
# Cümle: 'gün' 8895977. kelime, bir sonraki kelime: '(1955)'.
# Cümle: 'gün' 8911253. kelime, bir sonraki kelime: 'şarkı'.
# Cümle: 'gün' 8911596. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 8923199. kelime, bir sonraki kelime: 'sadece'.
# Cümle: 'gün' 8923265. kelime, bir sonraki kelime: 'tüm'.
# Cümle: 'gün' 8929756. kelime, bir sonraki kelime: 'sabah'.
# Cümle: 'gün' 8940953. kelime, bir sonraki kelime: 'ertesi'.
# Cümle: 'gün' 8940955. kelime, bir sonraki kelime: 'gayet'.
# Cümle: 'gün' 8961185. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 8972816. kelime, bir sonraki kelime: '9'.
# Cümle: 'gün' 8974040. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 8974131. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 8974168. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 8980999. kelime, bir sonraki kelime: 'yeniçaga'.
# Cümle: 'gün' 9011766. kelime, bir sonraki kelime: '(1948)'.
# Cümle: 'gün' 9014111. kelime, bir sonraki kelime: '173'.
# Cümle: 'gün' 9017171. kelime, bir sonraki kelime: 'başına'.
# Cümle: 'gün' 9023931. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 9029188. kelime, bir sonraki kelime: 'yakında:'.
# Cümle: 'gün' 9029286. kelime, bir sonraki kelime: '10.00)'.
# Cümle: 'gün' 9029302. kelime, bir sonraki kelime: '16.00)'.
# Cümle: 'gün' 9029393. kelime, bir sonraki kelime: 'ortası'.
# Cümle: 'gün' 9030501. kelime, bir sonraki kelime: '2018:'.
# Cümle: 'gün' 9030598. kelime, bir sonraki kelime: 'işığı'.
# Cümle: 'gün' 9033331. kelime, bir sonraki kelime: 'ortası'.
# Cümle: 'gün' 9033655. kelime, bir sonraki kelime: '('.
# Cümle: 'gün' 9034407. kelime, bir sonraki kelime: '(yakında)'.
# Cümle: 'gün' 9035328. kelime, bir sonraki kelime: '10:'.
# Cümle: 'gün' 9052557. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9060271. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9060665. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 9090286. kelime, bir sonraki kelime: 'teksas'.
# Cümle: 'gün' 9099740. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 9113338. kelime, bir sonraki kelime: 'çiçekleri,'.
# Cümle: 'gün' 9126750. kelime, bir sonraki kelime: '•'.
# Cümle: 'gün' 9132095. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9139233. kelime, bir sonraki kelime: 'geçirdikten'.
# Cümle: 'gün' 9145625. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9153220. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9153364. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9154901. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9189272. kelime, bir sonraki kelime: 'doğan'.
# Cümle: 'gün' 9228375. kelime, bir sonraki kelime: '"'.
# Cümle: 'gün' 9240750. kelime, bir sonraki kelime: 'içerisinde'.
# Cümle: 'gün' 9241066. kelime, bir sonraki kelime: 'içerisinde'.
# Cümle: 'gün' 9241187. kelime, bir sonraki kelime: 'önce,'.
# Cümle: 'gün' 9241372. kelime, bir sonraki kelime: 'sonrasına,'.
# Cümle: 'gün' 9242815. kelime, bir sonraki kelime: '14.30'.
# Cümle: 'gün' 9243494. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 9261202. kelime, bir sonraki kelime: 'onu'.
# Cümle: 'gün' 9261456. kelime, bir sonraki kelime: 'kampanya'.
# Cümle: 'gün' 9262320. kelime, bir sonraki kelime: 'siyasi'.
# Cümle: 'gün' 9262344. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 9296433. kelime, bir sonraki kelime: 'beşiktaş,'.
# Cümle: 'gün' 9313120. kelime, bir sonraki kelime: 'kadar'.
# Cümle: 'gün' 9316017. kelime, bir sonraki kelime: 'hapis'.
# Cümle: 'gün' 9319910. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 9322143. kelime, bir sonraki kelime: 'arasında'.
# Cümle: 'gün' 9322218. kelime, bir sonraki kelime: 'süreli'.
# Cümle: 'gün' 9327579. kelime, bir sonraki kelime: 'bolivya)'.
# Cümle: 'gün' 9329567. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 9329611. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 9332548. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9332586. kelime, bir sonraki kelime: 'güç'.
# Cümle: 'gün' 9337795. kelime, bir sonraki kelime: '•'.
# Cümle: 'gün' 9340725. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 9352960. kelime, bir sonraki kelime: 'adventist'.
# Cümle: 'gün' 9362835. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9370230. kelime, bir sonraki kelime: 'tekrar'.
# Cümle: 'gün' 9370242. kelime, bir sonraki kelime: 'kendisi'.
# Cümle: 'gün' 9381484. kelime, bir sonraki kelime: 'ölmekten'.
# Cümle: 'gün' 9391318. kelime, bir sonraki kelime: 'o'.
# Cümle: 'gün' 9392755. kelime, bir sonraki kelime: 'arkadaşı'.
# Cümle: 'gün' 9394921. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 9408684. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9408914. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9409317. kelime, bir sonraki kelime: 'i̇skoçya'ya'.
# Cümle: 'gün' 9411636. kelime, bir sonraki kelime: 'i̇ngiltere'.
# Cümle: 'gün' 9411991. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 9415265. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 9415920. kelime, bir sonraki kelime: 'cennete'.
# Cümle: 'gün' 9429191. kelime, bir sonraki kelime: 'kala'.
# Cümle: 'gün' 9432879. kelime, bir sonraki kelime: '2.457.600,5)'.
# Cümle: 'gün' 9432933. kelime, bir sonraki kelime: 'eğiklik'.
# Cümle: 'gün' 9437215. kelime, bir sonraki kelime: '(2008)'.
# Cümle: 'gün' 9437339. kelime, bir sonraki kelime: '(2007)'.
# Cümle: 'gün' 9441600. kelime, bir sonraki kelime: 'nivelle'.
# Cümle: 'gün' 9444158. kelime, bir sonraki kelime: 'zarfında'.
# Cümle: 'gün' 9450790. kelime, bir sonraki kelime: '1952'den'.
# Cümle: 'gün' 9451072. kelime, bir sonraki kelime: 'abd'.
# Cümle: 'gün' 9459911. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9479317. kelime, bir sonraki kelime: '2008:'.
# Cümle: 'gün' 9481332. kelime, bir sonraki kelime: 'cumhurbaşkanı'.
# Cümle: 'gün' 9481732. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9484782. kelime, bir sonraki kelime: 'jack,'.
# Cümle: 'gün' 9484843. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9484873. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9488701. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9488993. kelime, bir sonraki kelime: 'şam'a'.
# Cümle: 'gün' 9489606. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9489748. kelime, bir sonraki kelime: 'uzatarak'.
# Cümle: 'gün' 9489790. kelime, bir sonraki kelime: 'şam'a'.
# Cümle: 'gün' 9495444. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9499100. kelime, bir sonraki kelime: 'greg'.
# Cümle: 'gün' 9535889. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9535894. kelime, bir sonraki kelime: 'işığı'.
# Cümle: 'gün' 9536177. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9536184. kelime, bir sonraki kelime: 'işığı'.
# Cümle: 'gün' 9549332. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9578716. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 9579144. kelime, bir sonraki kelime: 'tutulan'.
# Cümle: 'gün' 9588966. kelime, bir sonraki kelime: 'doğmadan'.
# Cümle: 'gün' 9589592. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9592420. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 9598125. kelime, bir sonraki kelime: 'radyo'.
# Cümle: 'gün' 9599910. kelime, bir sonraki kelime: 'öncesinden'.
# Cümle: 'gün' 9604697. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 9604711. kelime, bir sonraki kelime: 'radyolarda'.
# Cümle: 'gün' 9611790. kelime, bir sonraki kelime: 'olmuştu.'.
# Cümle: 'gün' 9618180. kelime, bir sonraki kelime: 'osmanlı'.
# Cümle: 'gün' 9619081. kelime, bir sonraki kelime: 'caulaincourt'.
# Cümle: 'gün' 9626399. kelime, bir sonraki kelime: ':'.
# Cümle: 'gün' 9630078. kelime, bir sonraki kelime: 'olarak'.
# Cümle: 'gün' 9656249. kelime, bir sonraki kelime: 'ada'.
# Cümle: 'gün' 9673999. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9675627. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 9675831. kelime, bir sonraki kelime: 'içerisinde'.
# Cümle: 'gün' 9687706. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9704588. kelime, bir sonraki kelime: 'kimishima'.
# Cümle: 'gün' 9721422. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9721458. kelime, bir sonraki kelime: 'morgenthau'.
# Cümle: 'gün' 9721485. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9728280. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9745463. kelime, bir sonraki kelime: 'yıllık'.
# Cümle: 'gün' 9745829. kelime, bir sonraki kelime: 'yaş'.
# Cümle: 'gün' 9756312. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 9769081. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 9779657. kelime, bir sonraki kelime: 'baskı'.
# Cümle: 'gün' 9780041. kelime, bir sonraki kelime: 'sonunda'.
# Cümle: 'gün' 9802789. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9805955. kelime, bir sonraki kelime: 'adlı'.
# Cümle: 'gün' 9806118. kelime, bir sonraki kelime: '-'.
# Cümle: 'gün' 9806462. kelime, bir sonraki kelime: '-'.
# Cümle: 'gün' 9806655. kelime, bir sonraki kelime: '-'.
# Cümle: 'gün' 9817189. kelime, bir sonraki kelime: 'beklenmedik'.
# Cümle: 'gün' 9824240. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9840910. kelime, bir sonraki kelime: 'olmuştur;'.
# Cümle: 'gün' 9842031. kelime, bir sonraki kelime: 'yanına'.
# Cümle: 'gün' 9867742. kelime, bir sonraki kelime: '5.267'.
# Cümle: 'gün' 9878705. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 9882562. kelime, bir sonraki kelime: 'çeken'.
# Cümle: 'gün' 9882571. kelime, bir sonraki kelime: 'çekebilir.'.
# Cümle: 'gün' 9883769. kelime, bir sonraki kelime: 'han'.
# Cümle: 'gün' 9884829. kelime, bir sonraki kelime: 'ölmekten'.
# Cümle: 'gün' 9888898. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9889325. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9891473. kelime, bir sonraki kelime: 'batımından'.
# Cümle: 'gün' 9891800. kelime, bir sonraki kelime: 'batımı'.
# Cümle: 'gün' 9891878. kelime, bir sonraki kelime: 'batımı'.
# Cümle: 'gün' 9899358. kelime, bir sonraki kelime: '24'.
# Cümle: 'gün' 9906233. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9906237. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 9914862. kelime, bir sonraki kelime: 'eve'.
# Cümle: 'gün' 9920678. kelime, bir sonraki kelime: 'salko'.
# Cümle: 'gün' 9921611. kelime, bir sonraki kelime: 'maciej'.
# Cümle: 'gün' 9922965. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 9954829. kelime, bir sonraki kelime: 'süren,'.
# Cümle: 'gün' 9956416. kelime, bir sonraki kelime: 'öğleden'.
# Cümle: 'gün' 9968335. kelime, bir sonraki kelime: 'sevgilisinin'.
# Cümle: 'gün' 9969089. kelime, bir sonraki kelime: '16.45'te'.
# Cümle: 'gün' 9975814. kelime, bir sonraki kelime: 'imparator'.
# Cümle: 'gün' 9984122. kelime, bir sonraki kelime: 'mars'ta'.
# Cümle: 'gün' 9984132. kelime, bir sonraki kelime: '(6708'.
# Cümle: 'gün' 9986656. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 9995733. kelime, bir sonraki kelime: 'vardır'.
# Cümle: 'gün' 10012455. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 10030704. kelime, bir sonraki kelime: 'online'.
# Cümle: 'gün' 10030966. kelime, bir sonraki kelime: '"the'.
# Cümle: 'gün' 10062639. kelime, bir sonraki kelime: 'önce)'.
# Cümle: 'gün' 10065452. kelime, bir sonraki kelime: 'grubun'.
# Cümle: 'gün' 10070654. kelime, bir sonraki kelime: 'geçirdiler.'.
# Cümle: 'gün' 10092456. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 10092476. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 10092511. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 10097492. kelime, bir sonraki kelime: ''ün'.
# Cümle: 'gün' 10098233. kelime, bir sonraki kelime: '(1948)'.
# Cümle: 'gün' 10098739. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 10116874. kelime, bir sonraki kelime: 'hapis'.
# Cümle: 'gün' 10117221. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10127731. kelime, bir sonraki kelime: 'görülen'.
# Cümle: 'gün' 10145923. kelime, bir sonraki kelime: 'aniden'.
# Cümle: 'gün' 10145953. kelime, bir sonraki kelime: 'komadan'.
# Cümle: 'gün' 10154449. kelime, bir sonraki kelime: 'işığım'.
# Cümle: 'gün' 10154851. kelime, bir sonraki kelime: 'işığım'.
# Cümle: 'gün' 10192399. kelime, bir sonraki kelime: 'gökyüzünden'.
# Cümle: 'gün' 10205759. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 10209939. kelime, bir sonraki kelime: 'dayanabilen'.
# Cümle: 'gün' 10219621. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10224605. kelime, bir sonraki kelime: 'gerçekleşeceğini'.
# Cümle: 'gün' 10233794. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 10235901. kelime, bir sonraki kelime: 'ölmekten'.
# Cümle: 'gün' 10241389. kelime, bir sonraki kelime: 'açıklayamadığımız'.
# Cümle: 'gün' 10263775. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 10289830. kelime, bir sonraki kelime: 'gece'.
# Cümle: 'gün' 10295338. kelime, bir sonraki kelime: 'seul'.
# Cümle: 'gün' 10304366. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10305307. kelime, bir sonraki kelime: '·'.
# Cümle: 'gün' 10323539. kelime, bir sonraki kelime: 'rıza'ya'.
# Cümle: 'gün' 10357820. kelime, bir sonraki kelime: 'işareti'.
# Cümle: 'gün' 10388391. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 10388803. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 10394965. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 10397677. kelime, bir sonraki kelime: 'ayrılmak'.
# Cümle: 'gün' 10398402. kelime, bir sonraki kelime: '·'.
# Cümle: 'gün' 10398504. kelime, bir sonraki kelime: 'açacak'.
# Cümle: 'gün' 10398578. kelime, bir sonraki kelime: 'doğmadan'.
# Cümle: 'gün' 10406693. kelime, bir sonraki kelime: 'sonunda'.
# Cümle: 'gün' 10407411. kelime, bir sonraki kelime: 'türk'.
# Cümle: 'gün' 10407430. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10407545. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10407887. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 10431282. kelime, bir sonraki kelime: '•'.
# Cümle: 'gün' 10436321. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10436927. kelime, bir sonraki kelime: 'i̇çin'.
# Cümle: 'gün' 10454805. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 10465327. kelime, bir sonraki kelime: 'geri'.
# Cümle: 'gün' 10475859. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 10479424. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10484539. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10495195. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10549545. kelime, bir sonraki kelime: 'bir'.
# Cümle: 'gün' 10553088. kelime, bir sonraki kelime: 'gökyüzünde'.
# Cümle: 'gün' 10557152. kelime, bir sonraki kelime: 'ali'.
# Cümle: 'gün' 10579396. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 10579453. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 10579587. kelime, bir sonraki kelime: 'rangers'.
# Cümle: 'gün' 10579644. kelime, bir sonraki kelime: 'paris'.
# Cümle: 'gün' 10595669. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10633349. kelime, bir sonraki kelime: 'biraz'.
# Cümle: 'gün' 10633493. kelime, bir sonraki kelime: '60'.
# Cümle: 'gün' 10633552. kelime, bir sonraki kelime: '['.
# Cümle: 'gün' 10633594. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 10636172. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 10643256. kelime, bir sonraki kelime: 'ben'.
# Cümle: 'gün' 10643542. kelime, bir sonraki kelime: 'ben'.
# Cümle: 'gün' 10649323. kelime, bir sonraki kelime: 'caulaincourt'.
# Cümle: 'gün' 10663127. kelime, bir sonraki kelime: 'ışığı'.
# Cümle: 'gün' 10665756. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10666764. kelime, bir sonraki kelime: 'ayrıca'.
# Cümle: 'gün' 10683290. kelime, bir sonraki kelime: 'zileli'.
# Cümle: 'gün' 10689183. kelime, bir sonraki kelime: 'olduğu'.
# Cümle: 'gün' 10714918. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 10722178. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10722424. kelime, bir sonraki kelime: '1'.
# Cümle: 'gün' 10725321. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10732198. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10743570. kelime, bir sonraki kelime: 'öncesi'.
# Cümle: 'gün' 10743697. kelime, bir sonraki kelime: 'öncesi'.
# Cümle: 'gün' 10744117. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 10749501. kelime, bir sonraki kelime: 'i̇ş'.
# Cümle: 'gün' 10757067. kelime, bir sonraki kelime: '(1948)'.
# Cümle: 'gün' 10760069. kelime, bir sonraki kelime: 'babasının'.
# Cümle: 'gün' 10764344. kelime, bir sonraki kelime: 'ilerleyen'.
# Cümle: 'gün' 10764358. kelime, bir sonraki kelime: 'teslim'.
# Cümle: 'gün' 10765179. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10777721. kelime, bir sonraki kelime: 'nahçıvan'.
# Cümle: 'gün' 10779446. kelime, bir sonraki kelime: 'mahkum'.
# Cümle: 'gün' 10780044. kelime, bir sonraki kelime: 'yunus'.
# Cümle: 'gün' 10781074. kelime, bir sonraki kelime: 'leyla'.
# Cümle: 'gün' 10782078. kelime, bir sonraki kelime: 'fabrikanın'.
# Cümle: 'gün' 10785970. kelime, bir sonraki kelime: '24'.
# Cümle: 'gün' 10786094. kelime, bir sonraki kelime: 'sovyetler'.
# Cümle: 'gün' 10786236. kelime, bir sonraki kelime: 'albay'.
# Cümle: 'gün' 10794214. kelime, bir sonraki kelime: '(1977)'.
# Cümle: 'gün' 10794907. kelime, bir sonraki kelime: 'uzay'.
# Cümle: 'gün' 10795042. kelime, bir sonraki kelime: 'perihelion'.
# Cümle: 'gün' 10795933. kelime, bir sonraki kelime: 'kapatıldı'.
# Cümle: 'gün' 10834324. kelime, bir sonraki kelime: 'gibi'.
# Cümle: 'gün' 10834726. kelime, bir sonraki kelime: 'eğiklik'.
# Cümle: 'gün' 10839697. kelime, bir sonraki kelime: '(bir'.
# Cümle: 'gün' 10845999. kelime, bir sonraki kelime: 'geri'.
# Cümle: 'gün' 10846005. kelime, bir sonraki kelime: 'devam'.
# Cümle: 'gün' 10866147. kelime, bir sonraki kelime: 'kadar'.
# Cümle: 'gün' 10883499. kelime, bir sonraki kelime: '(2019)'.
# Cümle: 'gün' 10890691. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10902483. kelime, bir sonraki kelime: 'hastanede'.
# Cümle: 'gün' 10902517. kelime, bir sonraki kelime: 'kalan'.
# Cümle: 'gün' 10916076. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 10918248. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 10919502. kelime, bir sonraki kelime: 'el-gadiriye'.
# Cümle: 'gün' 10919652. kelime, bir sonraki kelime: 'hüseyin'in'.
# Cümle: 'gün' 10921044. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 10922463. kelime, bir sonraki kelime: 'kala'.
# Cümle: 'gün' 10929149. kelime, bir sonraki kelime: 'rahibeler'.
# Cümle: 'gün' 10929210. kelime, bir sonraki kelime: 'şehre'.
# Cümle: 'gün' 10940799. kelime, bir sonraki kelime: 'içindeki'.
# Cümle: 'gün' 10940892. kelime, bir sonraki kelime: 'yarışmacılar'.
# Cümle: 'gün' 10943977. kelime, bir sonraki kelime: '10-12'.
# Cümle: 'gün' 10945465. kelime, bir sonraki kelime: '10-12'.
# Cümle: 'gün' 10975162. kelime, bir sonraki kelime: 'kala'.
# Cümle: 'gün' 10975179. kelime, bir sonraki kelime: 'sovyetleri'.
# Cümle: 'gün' 10975474. kelime, bir sonraki kelime: 'sürdü)'.
# Cümle: 'gün' 10975515. kelime, bir sonraki kelime: 'sürelik'.
# Cümle: 'gün' 10976056. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10976229. kelime, bir sonraki kelime: 'kendi'.
# Cümle: 'gün' 10976447. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 10991932. kelime, bir sonraki kelime: 'zincirlikuyu'.
# Cümle: 'gün' 11012262. kelime, bir sonraki kelime: '(2018)'.
# Cümle: 'gün' 11020779. kelime, bir sonraki kelime: 'son'.
# Cümle: 'gün' 11020782. kelime, bir sonraki kelime: 'tarih'.
# Cümle: 'gün' 11034154. kelime, bir sonraki kelime: 'us-rda'.
# Cümle: 'gün' 11034176. kelime, bir sonraki kelime: 'askerîye'.
# Cümle: 'gün' 11034197. kelime, bir sonraki kelime: 'askerîye'.
# Cümle: 'gün' 11034244. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 11034268. kelime, bir sonraki kelime: 'askerîye'.
# Cümle: 'gün' 11034288. kelime, bir sonraki kelime: 'adema-pasj'.
# Cümle: 'gün' 11034312. kelime, bir sonraki kelime: 'rpm'.
# Cümle: 'gün' 11034336. kelime, bir sonraki kelime: 'askerîye'.
# Cümle: 'gün' 11034355. kelime, bir sonraki kelime: 'bağımsız'.
# Cümle: 'gün' 11034370. kelime, bir sonraki kelime: 'askerîye'.
# Cümle: 'gün' 11066832. kelime, bir sonraki kelime: 'saat'.
# Cümle: 'gün' 11066895. kelime, bir sonraki kelime: 'trenle'.
# Cümle: 'gün' 11067376. kelime, bir sonraki kelime: 'bir'.
# Cümle: 'gün' 11068384. kelime, bir sonraki kelime: 'macar'.
# Cümle: 'gün' 11068418. kelime, bir sonraki kelime: 'durum'.
# Cümle: 'gün' 11068886. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 11072858. kelime, bir sonraki kelime: 'iksirin'.
# Cümle: 'gün' 11090933. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 11110650. kelime, bir sonraki kelime: 'i̇çin'.
# Cümle: 'gün' 11111376. kelime, bir sonraki kelime: 'chicago'.
# Cümle: 'gün' 11111649. kelime, bir sonraki kelime: 'kafeteryada'.
# Cümle: 'gün' 11111681. kelime, bir sonraki kelime: 'önce,'.
# Cümle: 'gün' 11127275. kelime, bir sonraki kelime: 'elinde'.
# Cümle: 'gün' 11149247. kelime, bir sonraki kelime: 'geride'.
# Cümle: 'gün' 11155822. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 11170544. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11171401. kelime, bir sonraki kelime: 'görmelerini'.
# Cümle: 'gün' 11174484. kelime, bir sonraki kelime: 'nereden'.
# Cümle: 'gün' 11174975. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 11176009. kelime, bir sonraki kelime: 'önce,'.
# Cümle: 'gün' 11181300. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 11183001. kelime, bir sonraki kelime: 'azerbaycan'.
# Cümle: 'gün' 11183019. kelime, bir sonraki kelime: '(1)'.
# Cümle: 'gün' 11183031. kelime, bir sonraki kelime: '—'.
# Cümle: 'gün' 11183044. kelime, bir sonraki kelime: 'azerbaycan'.
# Cümle: 'gün' 11183061. kelime, bir sonraki kelime: '-'.
# Cümle: 'gün' 11183074. kelime, bir sonraki kelime: 'yeni'.
# Cümle: 'gün' 11183091. kelime, bir sonraki kelime: '4'.
# Cümle: 'gün' 11183103. kelime, bir sonraki kelime: 'son'.
# Cümle: 'gün' 11184632. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 11189012. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11190131. kelime, bir sonraki kelime: 'biri'.
# Cümle: 'gün' 11198928. kelime, bir sonraki kelime: 'devam'.
# Cümle: 'gün' 11198932. kelime, bir sonraki kelime: 'daha'.
# Cümle: 'gün' 11198969. kelime, bir sonraki kelime: 'daha'.
# Cümle: 'gün' 11200658. kelime, bir sonraki kelime: 'hanya'.
# Cümle: 'gün' 11207045. kelime, bir sonraki kelime: 'caulaincourt'.
# Cümle: 'gün' 11214207. kelime, bir sonraki kelime: 'marion'.
# Cümle: 'gün' 11214360. kelime, bir sonraki kelime: 'belirtilmeden'.
# Cümle: 'gün' 11218059. kelime, bir sonraki kelime: 'ilerleyen'.
# Cümle: 'gün' 11218073. kelime, bir sonraki kelime: 'teslim'.
# Cümle: 'gün' 11218894. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11233714. kelime, bir sonraki kelime: 'today's'.
# Cümle: 'gün' 11239291. kelime, bir sonraki kelime: 'yeni'.
# Cümle: 'gün' 11240310. kelime, bir sonraki kelime: 'halka'.
# Cümle: 'gün' 11248345. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 11248437. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 11261907. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11266241. kelime, bir sonraki kelime: 'leyla'.
# Cümle: 'gün' 11279232. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 11287511. kelime, bir sonraki kelime: '(1962)'.
# Cümle: 'gün' 11309625. kelime, bir sonraki kelime: 'olan'.
# Cümle: 'gün' 11315916. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 11325744. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 11330013. kelime, bir sonraki kelime: 'fayton'.
# Cümle: 'gün' 11338591. kelime, bir sonraki kelime: 'cumhurbaşkanlığı'.
# Cümle: 'gün' 11347808. kelime, bir sonraki kelime: 'egzersiz'.
# Cümle: 'gün' 11349495. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 11349970. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 11350014. kelime, bir sonraki kelime: 'mariya'.
# Cümle: 'gün' 11351034. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 11361221. kelime, bir sonraki kelime: 'ışığına'.
# Cümle: 'gün' 11364683. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 11372065. kelime, bir sonraki kelime: 'yaklaşık'.
# Cümle: 'gün' 11389050. kelime, bir sonraki kelime: 'arasında'.
# Cümle: 'gün' 11389257. kelime, bir sonraki kelime: 'sonrasına'.
# Cümle: 'gün' 11419954. kelime, bir sonraki kelime: 'düğün'.
# Cümle: 'gün' 11439421. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 11448836. kelime, bir sonraki kelime: 'tekrar'.
# Cümle: 'gün' 11469755. kelime, bir sonraki kelime: 'içerisinde'.
# Cümle: 'gün' 11486464. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 11486714. kelime, bir sonraki kelime: 'arap'.
# Cümle: 'gün' 11490317. kelime, bir sonraki kelime: 'yakında:'.
# Cümle: 'gün' 11490415. kelime, bir sonraki kelime: '10.00)'.
# Cümle: 'gün' 11490431. kelime, bir sonraki kelime: '16.00)'.
# Cümle: 'gün' 11490522. kelime, bir sonraki kelime: 'ortası'.
# Cümle: 'gün' 11491630. kelime, bir sonraki kelime: '2018:'.
# Cümle: 'gün' 11491727. kelime, bir sonraki kelime: 'işığı'.
# Cümle: 'gün' 11494460. kelime, bir sonraki kelime: 'ortası'.
# Cümle: 'gün' 11494784. kelime, bir sonraki kelime: '('.
# Cümle: 'gün' 11495536. kelime, bir sonraki kelime: '(yakında)'.
# Cümle: 'gün' 11498652. kelime, bir sonraki kelime: 'batımıyla'.
# Cümle: 'gün' 11498791. kelime, bir sonraki kelime: 'şölenlerle'.
# Cümle: 'gün' 11499204. kelime, bir sonraki kelime: 'oruç'.
# Cümle: 'gün' 11500624. kelime, bir sonraki kelime: 'sergilenen'.
# Cümle: 'gün' 11501193. kelime, bir sonraki kelime: 'tutmaktaydı'.
# Cümle: 'gün' 11501219. kelime, bir sonraki kelime: 'şabat'.
# Cümle: 'gün' 11501834. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11506172. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 11524169. kelime, bir sonraki kelime: 'hafta'.
# Cümle: 'gün' 11535550. kelime, bir sonraki kelime: 'olan'.
# Cümle: 'gün' 11541092. kelime, bir sonraki kelime: 'ilk'.
# Cümle: 'gün' 11552529. kelime, bir sonraki kelime: '&'.
# Cümle: 'gün' 11566642. kelime, bir sonraki kelime: 'atv'.
# Cümle: 'gün' 11567083. kelime, bir sonraki kelime: '6'.
# Cümle: 'gün' 11582217. kelime, bir sonraki kelime: ')'.
# Cümle: 'gün' 11582231. kelime, bir sonraki kelime: 'eğiklik'.
# Cümle: 'gün' 11593407. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 11618759. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 11647798. kelime, bir sonraki kelime: 'hastanesi'.
# Cümle: 'gün' 11657759. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 11659903. kelime, bir sonraki kelime: 'düşüncelerini'.
# Cümle: 'gün' 11661188. kelime, bir sonraki kelime: 'olacak'.
# Cümle: 'gün' 11700649. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11707811. kelime, bir sonraki kelime: 'yarışlar'.
# Cümle: 'gün' 11707834. kelime, bir sonraki kelime: 'arası'.
# Cümle: 'gün' 11711684. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 11716780. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11737657. kelime, bir sonraki kelime: '12'.
# Cümle: 'gün' 11739413. kelime, bir sonraki kelime: 'sazak'.
# Cümle: 'gün' 11748509. kelime, bir sonraki kelime: 'sonu'.
# Cümle: 'gün' 11759620. kelime, bir sonraki kelime: 'ağlarsın'.
# Cümle: 'gün' 11759717. kelime, bir sonraki kelime: 'ağlarsın'.
# Cümle: 'gün' 11759845. kelime, bir sonraki kelime: 'flash'.
# Cümle: 'gün' 11759890. kelime, bir sonraki kelime: 'almak'.
# Cümle: 'gün' 11768881. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 11768890. kelime, bir sonraki kelime: 'barbaros'.
# Cümle: 'gün' 11769918. kelime, bir sonraki kelime: 'bitmiştir.'.
# Cümle: 'gün' 11774949. kelime, bir sonraki kelime: 'babasının'.
# Cümle: 'gün' 11775948. kelime, bir sonraki kelime: 'ölmekten'.
# Cümle: 'gün' 11804591. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11811963. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 11812213. kelime, bir sonraki kelime: 'arap'.
# Cümle: 'gün' 11818344. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 11830495. kelime, bir sonraki kelime: 'onu'.
# Cümle: 'gün' 11853735. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 11853752. kelime, bir sonraki kelime: '29'.
# Cümle: 'gün' 11901469. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 11902226. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 11902262. kelime, bir sonraki kelime: 'kararını'.
# Cümle: 'gün' 11903096. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 11905718. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 11917925. kelime, bir sonraki kelime: 'döneceksin'.
# Cümle: 'gün' 11920682. kelime, bir sonraki kelime: 'sonrasına'.
# Cümle: 'gün' 11933165. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 11939694. kelime, bir sonraki kelime: 'parti'.
# Cümle: 'gün' 11940683. kelime, bir sonraki kelime: '1999'.
# Cümle: 'gün' 11940832. kelime, bir sonraki kelime: '2022'.
# Cümle: 'gün' 11940858. kelime, bir sonraki kelime: '2022'.
# Cümle: 'gün' 11944947. kelime, bir sonraki kelime: 'hayatına'.
# Cümle: 'gün' 11959082. kelime, bir sonraki kelime: 'resmi'.
# Cümle: 'gün' 11961162. kelime, bir sonraki kelime: 'hafta'.
# Cümle: 'gün' 11971535. kelime, bir sonraki kelime: 'sokağa'.
# Cümle: 'gün' 11973929. kelime, bir sonraki kelime: ')'.
# Cümle: 'gün' 11983244. kelime, bir sonraki kelime: 'gibi'.
# Cümle: 'gün' 11993361. kelime, bir sonraki kelime: 'stadyum'.
# Cümle: 'gün' 12014206. kelime, bir sonraki kelime: 'gece'.
# Cümle: 'gün' 12019421. kelime, bir sonraki kelime: '(şiir)'.
# Cümle: 'gün' 12026504. kelime, bir sonraki kelime: 'önerdi.'.
# Cümle: 'gün' 12081301. kelime, bir sonraki kelime: 'orada'.
# Cümle: 'gün' 12091855. kelime, bir sonraki kelime: 'ışığı'.
# Cümle: 'gün' 12104198. kelime, bir sonraki kelime: 'caulaincourt'.
# Cümle: 'gün' 12110590. kelime, bir sonraki kelime: 'üç'.
# Cümle: 'gün' 12112109. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 12113670. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 12124096. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 12124534. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12178623. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12203297. kelime, bir sonraki kelime: 'yağmurun'.
# Cümle: 'gün' 12203687. kelime, bir sonraki kelime: 'geceyi'.
# Cümle: 'gün' 12205583. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12221805. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 12226518. kelime, bir sonraki kelime: '('.
# Cümle: 'gün' 12227857. kelime, bir sonraki kelime: 'gazetesinin'.
# Cümle: 'gün' 12229866. kelime, bir sonraki kelime: 'yarışları'.
# Cümle: 'gün' 12230112. kelime, bir sonraki kelime: 'magne'.
# Cümle: 'gün' 12230257. kelime, bir sonraki kelime: 'maillot'.
# Cümle: 'gün' 12230279. kelime, bir sonraki kelime: 'maillot'.
# Cümle: 'gün' 12236293. kelime, bir sonraki kelime: '1.'.
# Cümle: 'gün' 12236400. kelime, bir sonraki kelime: '1.'.
# Cümle: 'gün' 12236605. kelime, bir sonraki kelime: '1.'.
# Cümle: 'gün' 12236717. kelime, bir sonraki kelime: '1.'.
# Cümle: 'gün' 12236795. kelime, bir sonraki kelime: '1.'.
# Cümle: 'gün' 12236894. kelime, bir sonraki kelime: '1.'.
# Cümle: 'gün' 12240865. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12261339. kelime, bir sonraki kelime: 'sayısı'.
# Cümle: 'gün' 12268823. kelime, bir sonraki kelime: 'boyu'.
# Cümle: 'gün' 12292202. kelime, bir sonraki kelime: '(2008)'.
# Cümle: 'gün' 12292266. kelime, bir sonraki kelime: '(1977)'.
# Cümle: 'gün' 12292360. kelime, bir sonraki kelime: 'işığım'.
# Cümle: 'gün' 12293494. kelime, bir sonraki kelime: 'sonrasına'.
# Cümle: 'gün' 12294901. kelime, bir sonraki kelime: 'olarak'.
# Cümle: 'gün' 12295168. kelime, bir sonraki kelime: 'arasında'.
# Cümle: 'gün' 12309736. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 12327401. kelime, bir sonraki kelime: 'covid-19'.
# Cümle: 'gün' 12333026. kelime, bir sonraki kelime: 'bir'.
# Cümle: 'gün' 12333918. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12342951. kelime, bir sonraki kelime: 'veya'.
# Cümle: 'gün' 12351611. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 12360571. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12360762. kelime, bir sonraki kelime: 'ise'.
# Cümle: 'gün' 12363097. kelime, bir sonraki kelime: 'öğretmeni'.
# Cümle: 'gün' 12367025. kelime, bir sonraki kelime: 'aşılmış,'.
# Cümle: 'gün' 12367028. kelime, bir sonraki kelime: 'daha'.
# Cümle: 'gün' 12367345. kelime, bir sonraki kelime: 'inkübasyonu'.
# Cümle: 'gün' 12367424. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12367435. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12368849. kelime, bir sonraki kelime: ')'.
# Cümle: 'gün' 12368862. kelime, bir sonraki kelime: 'eğiklik'.
# Cümle: 'gün' 12375317. kelime, bir sonraki kelime: '['.
# Cümle: 'gün' 12375376. kelime, bir sonraki kelime: '['.
# Cümle: 'gün' 12378407. kelime, bir sonraki kelime: 'başladı'.
# Cümle: 'gün' 12378665. kelime, bir sonraki kelime: 'beyoğlu,'.
# Cümle: 'gün' 12396225. kelime, bir sonraki kelime: 'vardır'.
# Cümle: 'gün' 12445176. kelime, bir sonraki kelime: 'leyla'.
# Cümle: 'gün' 12449763. kelime, bir sonraki kelime: 'önce,'.
# Cümle: 'gün' 12450033. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12457465. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 12468353. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 12480883. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 12494687. kelime, bir sonraki kelime: 'çoğu'.
# Cümle: 'gün' 12505628. kelime, bir sonraki kelime: 'en'.
# Cümle: 'gün' 12511349. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12512314. kelime, bir sonraki kelime: 'kala'.
# Cümle: 'gün' 12525964. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 12532391. kelime, bir sonraki kelime: '(14-16)'.
# Cümle: 'gün' 12545330. kelime, bir sonraki kelime: 'gibi'.
# Cümle: 'gün' 12552271. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 12553275. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 12564099. kelime, bir sonraki kelime: '(1962)'.
# Cümle: 'gün' 12575153. kelime, bir sonraki kelime: 'devriye'.
# Cümle: 'gün' 12588244. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 12596575. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12597195. kelime, bir sonraki kelime: 'kış'.
# Cümle: 'gün' 12598833. kelime, bir sonraki kelime: 'karşılıklı'.
# Cümle: 'gün' 12621651. kelime, bir sonraki kelime: 'eğiklik'.
# Cümle: 'gün' 12635357. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 12637843. kelime, bir sonraki kelime: 'i̇çin'.
# Cümle: 'gün' 12644755. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 12645653. kelime, bir sonraki kelime: 'hep'.
# Cümle: 'gün' 12680278. kelime, bir sonraki kelime: 'güneş,'.
# Cümle: 'gün' 12685822. kelime, bir sonraki kelime: 'kgb'.
# Cümle: 'gün' 12685882. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 12690895. kelime, bir sonraki kelime: 'ila'.
# Cümle: 'gün' 12692631. kelime, bir sonraki kelime: 'yürürlüğe'.
# Cümle: 'gün' 12709874. kelime, bir sonraki kelime: 'i.'.
# Cümle: 'gün' 12742611. kelime, bir sonraki kelime: 'seferi'.
# Cümle: 'gün' 12742646. kelime, bir sonraki kelime: 'quatre'.
# Cümle: 'gün' 12742863. kelime, bir sonraki kelime: 'randy'.
# Cümle: 'gün' 12755282. kelime, bir sonraki kelime: '19.00'.
# Cümle: 'gün' 12755311. kelime, bir sonraki kelime: '19.00,'.
# Cümle: 'gün' 12755316. kelime, bir sonraki kelime: '19.00'.
# Cümle: 'gün' 12755337. kelime, bir sonraki kelime: '19.00'.
# Cümle: 'gün' 12755343. kelime, bir sonraki kelime: '19.00'.
# Cümle: 'gün' 12755368. kelime, bir sonraki kelime: '19.00'da,'.
# Cümle: 'gün' 12755395. kelime, bir sonraki kelime: 'yayınlandı.'.
# Cümle: 'gün' 12755432. kelime, bir sonraki kelime: '19.00'da'.
# Cümle: 'gün' 12755441. kelime, bir sonraki kelime: '19.00'da'.
# Cümle: 'gün' 12755755. kelime, bir sonraki kelime: '(yakında)'.
# Cümle: 'gün' 12770857. kelime, bir sonraki kelime: 'britanya'.
# Cümle: 'gün' 12786846. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12788674. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 12791077. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 12800921. kelime, bir sonraki kelime: ').'.
# Cümle: 'gün' 12800947. kelime, bir sonraki kelime: ').'.
# Cümle: 'gün' 12800972. kelime, bir sonraki kelime: ').'.
# Cümle: 'gün' 12800996. kelime, bir sonraki kelime: ').'.
# Cümle: 'gün' 12857183. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12865057. kelime, bir sonraki kelime: 'önce,'.
# Cümle: 'gün' 12869010. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 12871573. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 12905830. kelime, bir sonraki kelime: 'toplanma'.
# Cümle: 'gün' 12909511. kelime, bir sonraki kelime: 'taarruzu'.
# Cümle: 'gün' 12918613. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 12920455. kelime, bir sonraki kelime: 'tutuklu'.
# Cümle: 'gün' 12925274. kelime, bir sonraki kelime: '0.3781'.
# Cümle: 'gün' 12937899. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 12973087. kelime, bir sonraki kelime: 'fotoğraf'.
# Cümle: 'gün' 12973165. kelime, bir sonraki kelime: 'fotoğraf'.
# Cümle: 'gün' 12976122. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 12977550. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 12991763. kelime, bir sonraki kelime: 'bir'.
# Cümle: 'gün' 12991777. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 12991802. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 12992694. kelime, bir sonraki kelime: 'sayısı'.
# Cümle: 'gün' 13011654. kelime, bir sonraki kelime: 'batımı'.
# Cümle: 'gün' 13019016. kelime, bir sonraki kelime: 'adventist'.
# Cümle: 'gün' 13019529. kelime, bir sonraki kelime: 'doğumu'.
# Cümle: 'gün' 13035635. kelime, bir sonraki kelime: 'batımı'.
# Cümle: 'gün' 13043838. kelime, bir sonraki kelime: 'aldığı'.
# Cümle: 'gün' 13054631. kelime, bir sonraki kelime: 'zeynep'.
# Cümle: 'gün' 13072498. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 13072506. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 13149332. kelime, bir sonraki kelime: 'yeni'.
# Cümle: 'gün' 13163563. kelime, bir sonraki kelime: 'kadar'.
# Cümle: 'gün' 13165339. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 13165506. kelime, bir sonraki kelime: 'devam'.
# Cümle: 'gün' 13165513. kelime, bir sonraki kelime: 'evden'.
# Cümle: 'gün' 13165617. kelime, bir sonraki kelime: 'öncesinden'.
# Cümle: 'gün' 13166054. kelime, bir sonraki kelime: 'önceden'.
# Cümle: 'gün' 13166264. kelime, bir sonraki kelime: 'kutlanır'.
# Cümle: 'gün' 13166268. kelime, bir sonraki kelime: 'ayrıca'.
# Cümle: 'gün' 13171405. kelime, bir sonraki kelime: 'muhasara'.
# Cümle: 'gün' 13184376. kelime, bir sonraki kelime: 'not,'.
# Cümle: 'gün' 13197648. kelime, bir sonraki kelime: 'bir'.
# Cümle: 'gün' 13208411. kelime, bir sonraki kelime: 'i̇sviçre'.
# Cümle: 'gün' 13208500. kelime, bir sonraki kelime: 'ss'.
# Cümle: 'gün' 13220872. kelime, bir sonraki kelime: 'ölmekten'.
# Cümle: 'gün' 13221115. kelime, bir sonraki kelime: '(tek'.
# Cümle: 'gün' 13221288. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 13221294. kelime, bir sonraki kelime: 'arasında'.
# Cümle: 'gün' 13223790. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13229625. kelime, bir sonraki kelime: 'boyunu'.
# Cümle: 'gün' 13229653. kelime, bir sonraki kelime: 'hayatı'.
# Cümle: 'gün' 13229660. kelime, bir sonraki kelime: 'geldiğinde'.
# Cümle: 'gün' 13255453. kelime, bir sonraki kelime: 'son'.
# Cümle: 'gün' 13255456. kelime, bir sonraki kelime: 'tarih'.
# Cümle: 'gün' 13270027. kelime, bir sonraki kelime: 'tutuklu'.
# Cümle: 'gün' 13270032. kelime, bir sonraki kelime: 'syros'.
# Cümle: 'gün' 13270073. kelime, bir sonraki kelime: 'maguire'a'.
# Cümle: 'gün' 13270078. kelime, bir sonraki kelime: 'hapis'.
# Cümle: 'gün' 13274955. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 13282842. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 13283472. kelime, bir sonraki kelime: 'işığım'.
# Cümle: 'gün' 13283701. kelime, bir sonraki kelime: 'işığım'.
# Cümle: 'gün' 13290226. kelime, bir sonraki kelime: 'ölmüştür.'.
# Cümle: 'gün' 13312141. kelime, bir sonraki kelime: 'boğmak'.
# Cümle: 'gün' 13315223. kelime, bir sonraki kelime: 'ışığına'.
# Cümle: 'gün' 13323171. kelime, bir sonraki kelime: 'kar'.
# Cümle: 'gün' 13334605. kelime, bir sonraki kelime: 'homer,'.
# Cümle: 'gün' 13335093. kelime, bir sonraki kelime: 'haftayı'.
# Cümle: 'gün' 13355552. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 13373871. kelime, bir sonraki kelime: 'kısaltıldı.'.
# Cümle: 'gün' 13390647. kelime, bir sonraki kelime: 'ışığı'.
# Cümle: 'gün' 13436296. kelime, bir sonraki kelime: 'filipinler'.
# Cümle: 'gün' 13446774. kelime, bir sonraki kelime: 'birkaç'.
# Cümle: 'gün' 13446955. kelime, bir sonraki kelime: 'reuters'e'.
# Cümle: 'gün' 13464607. kelime, bir sonraki kelime: 'sadrazamlık'.
# Cümle: 'gün' 13465121. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13476952. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13492063. kelime, bir sonraki kelime: 'kaldıktan'.
# Cümle: 'gün' 13505253. kelime, bir sonraki kelime: 'adventist'.
# Cümle: 'gün' 13505480. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13539658. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 13576726. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13592692. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 13595131. kelime, bir sonraki kelime: 'önce.)'.
# Cümle: 'gün' 13597754. kelime, bir sonraki kelime: 'ölmekten'.
# Cümle: 'gün' 13603531. kelime, bir sonraki kelime: '2'.
# Cümle: 'gün' 13635948. kelime, bir sonraki kelime: 'akşam'.
# Cümle: 'gün' 13638638. kelime, bir sonraki kelime: 'akşam'.
# Cümle: 'gün' 13685000. kelime, bir sonraki kelime: 'zindandan'.
# Cümle: 'gün' 13691081. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 13691397. kelime, bir sonraki kelime: 'boyu'.
# Cümle: 'gün' 13691478. kelime, bir sonraki kelime: 'sonunda'.
# Cümle: 'gün' 13691501. kelime, bir sonraki kelime: 'boyu'.
# Cümle: 'gün' 13692150. kelime, bir sonraki kelime: 'taarruzları,'.
# Cümle: 'gün' 13692258. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 13692265. kelime, bir sonraki kelime: 'hedeflerinin'.
# Cümle: 'gün' 13696217. kelime, bir sonraki kelime: 'sedat'.
# Cümle: 'gün' 13696856. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13700055. kelime, bir sonraki kelime: 'ülkesine'.
# Cümle: 'gün' 13704160. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 13704410. kelime, bir sonraki kelime: 'arap'.
# Cümle: 'gün' 13713483. kelime, bir sonraki kelime: 'dizinin'.
# Cümle: 'gün' 13724073. kelime, bir sonraki kelime: 'sayısı'.
# Cümle: 'gün' 13724078. kelime, bir sonraki kelime: 'sayısı'.
# Cümle: 'gün' 13724082. kelime, bir sonraki kelime: 'sayısı'.
# Cümle: 'gün' 13725091. kelime, bir sonraki kelime: 'i̇stanbul'.
# Cümle: 'gün' 13728611. kelime, bir sonraki kelime: 'zileli'.
# Cümle: 'gün' 13770621. kelime, bir sonraki kelime: 'önce)'.
# Cümle: 'gün' 13777565. kelime, bir sonraki kelime: 'veya'.
# Cümle: 'gün' 13787657. kelime, bir sonraki kelime: 'yayınlanıyor?"'.
# Cümle: 'gün' 13793280. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 13794172. kelime, bir sonraki kelime: 'oyunun'.
# Cümle: 'gün' 13801559. kelime, bir sonraki kelime: 'film'.
# Cümle: 'gün' 13806364. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 13825490. kelime, bir sonraki kelime: 'dinlendiği'.
# Cümle: 'gün' 13830033. kelime, bir sonraki kelime: 'daha'.
# Cümle: 'gün' 13840863. kelime, bir sonraki kelime: 'yaşar'.
# Cümle: 'gün' 13842810. kelime, bir sonraki kelime: 'gheldorode'.
# Cümle: 'gün' 13870421. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 13879660. kelime, bir sonraki kelime: '(müştereken'.
# Cümle: 'gün' 13882507. kelime, bir sonraki kelime: 'kadar'.
# Cümle: 'gün' 13888026. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 13889673. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 13901305. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 13920323. kelime, bir sonraki kelime: 'anısına'.
# Cümle: 'gün' 13928443. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 13941043. kelime, bir sonraki kelime: 'kral'.
# Cümle: 'gün' 13943400. kelime, bir sonraki kelime: 'üst'.
# Cümle: 'gün' 13944783. kelime, bir sonraki kelime: 'denizde'.
# Cümle: 'gün' 13975658. kelime, bir sonraki kelime: 'sadrazamlık'.
# Cümle: 'gün' 13979096. kelime, bir sonraki kelime: 'sadrazamlık'.
# Cümle: 'gün' 13979112. kelime, bir sonraki kelime: 'sadrazamlık'.
# Cümle: 'gün' 13979267. kelime, bir sonraki kelime: 'serdar'.
# Cümle: 'gün' 13979461. kelime, bir sonraki kelime: 'sürdü.'.
# Cümle: 'gün' 13984214. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 13984217. kelime, bir sonraki kelime: '80'.
# Cümle: 'gün' 13988339. kelime, bir sonraki kelime: 'geç'.
# Cümle: 'gün' 14000375. kelime, bir sonraki kelime: 'ışığı'.
# Cümle: 'gün' 14012643. kelime, bir sonraki kelime: 'başka'.
# Cümle: 'gün' 14027655. kelime, bir sonraki kelime: 'yetecek'.
# Cümle: 'gün' 14027665. kelime, bir sonraki kelime: 'yetecek'.
# Cümle: 'gün' 14028223. kelime, bir sonraki kelime: 'yetecek'.
# ...
# Cümle: 'gün' 36191601. kelime, bir sonraki kelime: 'westminster'.
# Cümle: 'gün' 36200407. kelime, bir sonraki kelime: 'okulu'.
# Cümle: 'gün' 36204004. kelime, bir sonraki kelime: 'kala'.
# Cümle: 'gün' 36215915. kelime, bir sonraki kelime: 'nasıl'.
# Cümle: 'gün' 36220080. kelime, bir sonraki kelime: 'i̇çin'.
# Cümle: 'gün' 36256768. kelime, bir sonraki kelime: 'leyla'.
# Cümle: 'gün' 36257275. kelime, bir sonraki kelime: 'özlersin'.
# Cümle: 'gün' 36263980. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36268272. kelime, bir sonraki kelime: 'süren'.
# Cümle: 'gün' 36271198. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 36279320. kelime, bir sonraki kelime: 'sürer.'.
# Cümle: 'gün' 36286615. kelime, bir sonraki kelime: '['.
# Cümle: 'gün' 36303773. kelime, bir sonraki kelime: '27'.
# Cümle: 'gün' 36312001. kelime, bir sonraki kelime: 'beynəlxalq'.
# Cümle: 'gün' 36323915. kelime, bir sonraki kelime: 'thiago'.
# Cümle: 'gün' 36343715. kelime, bir sonraki kelime: 'ruble-dolar'.
# Cümle: 'gün' 36345637. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 36346443. kelime, bir sonraki kelime: 'gördüğümüz'.
# Cümle: 'gün' 36346564. kelime, bir sonraki kelime: 'fiziken'.
# Cümle: 'gün' 36351222. kelime, bir sonraki kelime: 'önceyse;'.
# Cümle: 'gün' 36351383. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 36351807. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 36351849. kelime, bir sonraki kelime: '64'.
# Cümle: 'gün' 36352658. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36352724. kelime, bir sonraki kelime: 'ilerledikçe,'.
# Cümle: 'gün' 36353228. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36353506. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36353631. kelime, bir sonraki kelime: 'fransız'.
# Cümle: 'gün' 36353690. kelime, bir sonraki kelime: 'buradaydılar.'.
# Cümle: 'gün' 36354489. kelime, bir sonraki kelime: 'yaralanan'.
# Cümle: 'gün' 36354639. kelime, bir sonraki kelime: '2'.
# Cümle: 'gün' 36356002. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36356079. kelime, bir sonraki kelime: 'gambetta'.
# Cümle: 'gün' 36359252. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36365408. kelime, bir sonraki kelime: 'tapınağı'.
# Cümle: 'gün' 36365603. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 36378445. kelime, bir sonraki kelime: 'arasında'.
# Cümle: 'gün' 36378728. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36387880. kelime, bir sonraki kelime: 'listelerde'.
# Cümle: 'gün' 36393572. kelime, bir sonraki kelime: '24'.
# Cümle: 'gün' 36418716. kelime, bir sonraki kelime: 'moskova'.
# Cümle: 'gün' 36436741. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36436840. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36450757. kelime, bir sonraki kelime: 'elektra'dan'.
# Cümle: 'gün' 36450762. kelime, bir sonraki kelime: 'içinde,'.
# Cümle: 'gün' 36454937. kelime, bir sonraki kelime: 'sayısını'.
# Cümle: 'gün' 36455171. kelime, bir sonraki kelime: 'sürerdi.'.
# Cümle: 'gün' 36491528. kelime, bir sonraki kelime: 'sonrasında'.
# Cümle: 'gün' 36493490. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 36494645. kelime, bir sonraki kelime: 'ağarmadan'.
# Cümle: 'gün' 36495872. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 36495893. kelime, bir sonraki kelime: 'içinde,'.
# Cümle: 'gün' 36496048. kelime, bir sonraki kelime: '2'.
# Cümle: 'gün' 36496069. kelime, bir sonraki kelime: 'daha'.
# Cümle: 'gün' 36497209. kelime, bir sonraki kelime: 'geçirdi'.
# Cümle: 'gün' 36497627. kelime, bir sonraki kelime: 'patlamanın'.
# Cümle: 'gün' 36499599. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 36500635. kelime, bir sonraki kelime: 'ayrımcılık'.
# Cümle: 'gün' 36501369. kelime, bir sonraki kelime: 'çaba'.
# Cümle: 'gün' 36502761. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 36503283. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36503911. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 36504229. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 36504951. kelime, bir sonraki kelime: 'önce,'.
# Cümle: 'gün' 36506241. kelime, bir sonraki kelime: 'sonra),'.
# Cümle: 'gün' 36526657. kelime, bir sonraki kelime: '•'.
# Cümle: 'gün' 36533220. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 36544524. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36544540. kelime, bir sonraki kelime: 'skandal'.
# Cümle: 'gün' 36579684. kelime, bir sonraki kelime: 'için'.
# Cümle: 'gün' 36611835. kelime, bir sonraki kelime: 'kuşatma'.
# Cümle: 'gün' 36613554. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 36616168. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 36616606. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36624334. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 36643258. kelime, bir sonraki kelime: 'yaptığı'.
# Cümle: 'gün' 36648388. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36654810. kelime, bir sonraki kelime: 'işığım'.
# Cümle: 'gün' 36658238. kelime, bir sonraki kelime: 'yine'.
# Cümle: 'gün' 36658253. kelime, bir sonraki kelime: 'ölürler.'.
# Cümle: 'gün' 36667738. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36679281. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 36687965. kelime, bir sonraki kelime: '(1899).'.
# Cümle: 'gün' 36693795. kelime, bir sonraki kelime: 'yolculuk'.
# Cümle: 'gün' 36693902. kelime, bir sonraki kelime: 'çalışmakta'.
# Cümle: 'gün' 36695489. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36722480. kelime, bir sonraki kelime: '2000:'.
# Cümle: 'gün' 36736502. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 36737496. kelime, bir sonraki kelime: 'sonrasında'.
# Cümle: 'gün' 36757237. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 36759321. kelime, bir sonraki kelime: '(devam'.
# Cümle: 'gün' 36761623. kelime, bir sonraki kelime: '-'.
# Cümle: 'gün' 36765990. kelime, bir sonraki kelime: 'uçmasına'.
# Cümle: 'gün' 36778501. kelime, bir sonraki kelime: 'fethullah'.
# Cümle: 'gün' 36778677. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36779040. kelime, bir sonraki kelime: 'i̇stanbul'.
# Cümle: 'gün' 36779649. kelime, bir sonraki kelime: 'yaptığı'.
# Cümle: 'gün' 36779691. kelime, bir sonraki kelime: 'danıştay,'.
# Cümle: 'gün' 36779952. kelime, bir sonraki kelime: '(31'.
# Cümle: 'gün' 36780058. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36780474. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 36780844. kelime, bir sonraki kelime: 'kemal'.
# Cümle: 'gün' 36780931. kelime, bir sonraki kelime: 'yeni'.
# Cümle: 'gün' 36791827. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 36795226. kelime, bir sonraki kelime: '•'.
# Cümle: 'gün' 36798382. kelime, bir sonraki kelime: 'yas'.
# Cümle: 'gün' 36798528. kelime, bir sonraki kelime: 'isyan'.
# Cümle: 'gün' 36815629. kelime, bir sonraki kelime: '1984:'.
# Cümle: 'gün' 36826269. kelime, bir sonraki kelime: '(288'.
# Cümle: 'gün' 36873021. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 36878614. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36886001. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 36886208. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 36917044. kelime, bir sonraki kelime: 'suat'.
# Cümle: 'gün' 36943693. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 36944907. kelime, bir sonraki kelime: '(5,59'.
# Cümle: 'gün' 36959915. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 36960201. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 36962038. kelime, bir sonraki kelime: 'güneşlidir.'.
# Cümle: 'gün' 36962231. kelime, bir sonraki kelime: 'kapalı'.
# Cümle: 'gün' 37025923. kelime, bir sonraki kelime: 'ufak'.
# Cümle: 'gün' 37029465. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37030731. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37030802. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 37044913. kelime, bir sonraki kelime: '-'.
# Cümle: 'gün' 37045996. kelime, bir sonraki kelime: 'vardır'.
# Cümle: 'gün' 37046805. kelime, bir sonraki kelime: 'ağır'.
# Cümle: 'gün' 37053874. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37054000. kelime, bir sonraki kelime: 'değişikliklerinden'.
# Cümle: 'gün' 37056137. kelime, bir sonraki kelime: 'zileli'.
# Cümle: 'gün' 37074575. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37078691. kelime, bir sonraki kelime: 'ile'.
# Cümle: 'gün' 37078734. kelime, bir sonraki kelime: 'ile'.
# Cümle: 'gün' 37097289. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37098222. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37098434. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37100955. kelime, bir sonraki kelime: 'lisenin'.
# Cümle: 'gün' 37148671. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37154868. kelime, bir sonraki kelime: 'günlük'.
# Cümle: 'gün' 37202474. kelime, bir sonraki kelime: '•'.
# Cümle: 'gün' 37237693. kelime, bir sonraki kelime: 'aç'.
# Cümle: 'gün' 37237780. kelime, bir sonraki kelime: 'geçmeden'.
# Cümle: 'gün' 37238813. kelime, bir sonraki kelime: 'öğle'.
# Cümle: 'gün' 37245501. kelime, bir sonraki kelime: 'saat'.
# Cümle: 'gün' 37262011. kelime, bir sonraki kelime: 'sonraki'.
# Cümle: 'gün' 37263920. kelime, bir sonraki kelime: 'yerel'.
# Cümle: 'gün' 37263969. kelime, bir sonraki kelime: 'gerçekleşti.'.
# Cümle: 'gün' 37278524. kelime, bir sonraki kelime: 'ghamdan'.
# Cümle: 'gün' 37294998. kelime, bir sonraki kelime: '5.tahsin'.
# Cümle: 'gün' 37314241. kelime, bir sonraki kelime: 'artan'.
# Cümle: 'gün' 37328607. kelime, bir sonraki kelime: 'de'.
# Cümle: 'gün' 37348709. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37361150. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37361889. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 37362441. kelime, bir sonraki kelime: 'sürdü,'.
# Cümle: 'gün' 37390118. kelime, bir sonraki kelime: '(pazar)'.
# Cümle: 'gün' 37390220. kelime, bir sonraki kelime: 'jess'.
# Cümle: 'gün' 37392581. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37398810. kelime, bir sonraki kelime: ','.
# Cümle: 'gün' 37404960. kelime, bir sonraki kelime: '(ebru'.
# Cümle: 'gün' 37414374. kelime, bir sonraki kelime: 'taarruzu'.
# Cümle: 'gün' 37428320. kelime, bir sonraki kelime: 'bağımsızlığı'.
# Cümle: 'gün' 37436606. kelime, bir sonraki kelime: 'vardır.'.
# Cümle: 'gün' 37467750. kelime, bir sonraki kelime: 'herkesin'.
# Cümle: 'gün' 37471526. kelime, bir sonraki kelime: '('.
# Cümle: 'gün' 37471580. kelime, bir sonraki kelime: 'iain'.
# Cümle: 'gün' 37476723. kelime, bir sonraki kelime: 'tutuklandı'.
# Cümle: 'gün' 37482098. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37482478. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 37482965. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37483578. kelime, bir sonraki kelime: 'açıklanan'.
# Cümle: 'gün' 37484019. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 37495561. kelime, bir sonraki kelime: 'yüzüne'.
# Cümle: 'gün' 37508265. kelime, bir sonraki kelime: '16.00-18.00'.
# Cümle: 'gün' 37514780. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 37527552. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37531981. kelime, bir sonraki kelime: '(1965)'.
# Cümle: 'gün' 37532043. kelime, bir sonraki kelime: '(1971)'.
# Cümle: 'gün' 37533297. kelime, bir sonraki kelime: 'bitecek'.
# Cümle: 'gün' 37534495. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37550085. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37552773. kelime, bir sonraki kelime: 'öldürüldü.'.
# Cümle: 'gün' 37564069. kelime, bir sonraki kelime: 'adventist'.
# Cümle: 'gün' 37566586. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 37589543. kelime, bir sonraki kelime: 'ışığına'.
# Cümle: 'gün' 37598385. kelime, bir sonraki kelime: 'geçtikçe'.
# Cümle: 'gün' 37605417. kelime, bir sonraki kelime: 'meydana'.
# Cümle: 'gün' 37617216. kelime, bir sonraki kelime: 'boyu'.
# Cümle: 'gün' 37626692. kelime, bir sonraki kelime: 'oğlu'.
# Cümle: 'gün' 37626825. kelime, bir sonraki kelime: 'saltanat'.
# Cümle: 'gün' 37627240. kelime, bir sonraki kelime: 'yas'.
# Cümle: 'gün' 37628107. kelime, bir sonraki kelime: 'içerisinde'.
# Cümle: 'gün' 37628133. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37630387. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37630550. kelime, bir sonraki kelime: 'sonra,'.
# Cümle: 'gün' 37631777. kelime, bir sonraki kelime: 'şiddetle'.
# Cümle: 'gün' 37631887. kelime, bir sonraki kelime: 'kadar'.
# Cümle: 'gün' 37631896. kelime, bir sonraki kelime: 'kadar,'.
# Cümle: 'gün' 37631958. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37631976. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 37632012. kelime, bir sonraki kelime: 'geçit'.
# Cümle: 'gün' 37632166. kelime, bir sonraki kelime: 've'.
# Cümle: 'gün' 37633459. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37633497. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37633557. kelime, bir sonraki kelime: 'eksikti.'.
# Cümle: 'gün' 37654933. kelime, bir sonraki kelime: 'savaşı'.
# Cümle: 'gün' 37660384. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37694700. kelime, bir sonraki kelime: '(2019)'.
# Cümle: 'gün' 37697278. kelime, bir sonraki kelime: 'ışığına'.
# Cümle: 'gün' 37701469. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 37701810. kelime, bir sonraki kelime: 'içinde'.
# Cümle: 'gün' 37703181. kelime, bir sonraki kelime: 'gece'.
# Cümle: 'gün' 37725474. kelime, bir sonraki kelime: 'kişi'.
# Cümle: 'gün' 37725534. kelime, bir sonraki kelime: 'araştırma'.
# Cümle: 'gün' 37748133. kelime, bir sonraki kelime: 'mahsur'.
# Cümle: 'gün' 37754599. kelime, bir sonraki kelime: 'önce.)'.
# Cümle: 'gün' 37755292. kelime, bir sonraki kelime: 'almamış'.
# Cümle: 'gün' 37765018. kelime, bir sonraki kelime: 'andrea'.
# Cümle: 'gün' 37784574. kelime, bir sonraki kelime: 'millî'.
# Cümle: 'gün' 37785188. kelime, bir sonraki kelime: 'oynanan'.
# Cümle: 'gün' 37796416. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 37796693. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 37796916. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 37825563. kelime, bir sonraki kelime: 'uzmanlık'.
# Cümle: 'gün' 37825584. kelime, bir sonraki kelime: 'nedenleri'.
# Cümle: 'gün' 37825634. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37825666. kelime, bir sonraki kelime: 'sürer,'.
# Cümle: 'gün' 37835911. kelime, bir sonraki kelime: 'dayanışmayı'.
# Cümle: 'gün' 37847494. kelime, bir sonraki kelime: 'han'.
# Cümle: 'gün' 37869560. kelime, bir sonraki kelime: 'bir'.
# Cümle: 'gün' 37885982. kelime, bir sonraki kelime: 'batımı'.
# Cümle: 'gün' 37918399. kelime, bir sonraki kelime: 'uzun'.
# Cümle: 'gün' 37929019. kelime, bir sonraki kelime: '(17'.
# Cümle: 'gün' 37929438. kelime, bir sonraki kelime: '(18'.
# Cümle: 'gün' 37929823. kelime, bir sonraki kelime: '(19'.
# Cümle: 'gün' 37930234. kelime, bir sonraki kelime: '(20'.
# Cümle: 'gün' 37930677. kelime, bir sonraki kelime: '(21'.
# Cümle: 'gün' 37931206. kelime, bir sonraki kelime: '(22'.
# Cümle: 'gün' 37931700. kelime, bir sonraki kelime: '(23'.
# Cümle: 'gün' 37932178. kelime, bir sonraki kelime: '(24'.
# Cümle: 'gün' 37932632. kelime, bir sonraki kelime: '(25'.
# Cümle: 'gün' 37933022. kelime, bir sonraki kelime: '(26'.
# Cümle: 'gün' 37933305. kelime, bir sonraki kelime: '(27'.
# Cümle: 'gün' 37933525. kelime, bir sonraki kelime: '(28'.
# Cümle: 'gün' 37933725. kelime, bir sonraki kelime: '(29'.
# Cümle: 'gün' 37933856. kelime, bir sonraki kelime: '(30'.
# Cümle: 'gün' 37936224. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37946359. kelime, bir sonraki kelime: 'önce'.
# Cümle: 'gün' 37946478. kelime, bir sonraki kelime: 'sonra'.
# Cümle: 'gün' 37971654. kelime, bir sonraki kelime: 'veya'.
# Cümle: 'gün' 37983440. kelime, bir sonraki kelime: '"i'm'.
# Cümle: 'gün' 37983589. kelime, bir sonraki kelime: '"i'm'.
# Cümle: 'gün' 37991428. kelime, bir sonraki kelime: 'japon'.
# Cümle: 'gün' 37991489. kelime, bir sonraki kelime: 'kanagawa'.
# Cümle: 'gün' 37991668. kelime, bir sonraki kelime: 'ilk'.
# Cümle: 'gün' 37991901. kelime, bir sonraki kelime: 'kaldırıldı.'.
# Cümle: 'gün' 37992073. kelime, bir sonraki kelime: 'boyunca'.
# Cümle: 'gün' 37998126. kelime, bir sonraki kelime: 'gerilemektedir.'.
# Cümle: 'gün' 38043905. kelime, bir sonraki kelime: 'eğiklik'.
# Cümle: 'gün' 38047822. kelime, bir sonraki kelime: 'değil,'.
# Cümle: 'gün' 38052819. kelime, bir sonraki kelime: 'gibi/yalancı'.
# Cümle: 'gün' 38054392. kelime, bir sonraki kelime: 'gibi'.
# --------------------------------------------------
